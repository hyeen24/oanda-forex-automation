# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os

# %%
load_dotenv()
API_KEY = os.getenv("API_KEY")
ACCOUNT_ID = os.getenv("ACCOUNT_ID")
URL = os.getenv("OANDA_URL")
SECURE_HEADER = {
    'Authorization': f'Bearer {API_KEY}'
}

# %% [markdown]
# #### Fetch data from oanda

# %%
def fetch_data(instrument="AUD_CHF", granularity="M15", count=5000):
    session = requests.Session()

    params = {
        "count": count,
        "granularity": granularity,
    }

    url = f"{URL}/instruments/{instrument}/candles"
    response = session.get(url, params=params, headers=SECURE_HEADER) 
    
    return response.json()

# %%
# Test fetch data function
raw_data = fetch_data("EUR_USD","M1", 5000)
raw_data
# Out:
# {'instrument': 'EUR_USD',
#  'granularity': 'M1',
#  'candles': [{'complete': True,
#    'volume': 87,
#    'time': '2025-01-03T20:20:00.000000000Z',
#    'mid': {'o': '1.03060', 'h': '1.03064', 'l': '1.03048', 'c': '1.03053'}},
#   {'complete': True,
#    'volume': 59,
#    'time': '2025-01-03T20:21:00.000000000Z',
#    'mid': {'o': '1.03051', 'h': '1.03054', 'l': '1.03048', 'c': '1.03053'}},
#   {'complete': True,
#    'volume': 50,
#    'time': '2025-01-03T20:22:00.000000000Z',
#    'mid': {'o': '1.03055', 'h': '1.03062', 'l': '1.03052', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 29,
#    'time': '2025-01-03T20:23:00.000000000Z',
#    'mid': {'o': '1.03061', 'h': '1.03062', 'l': '1.03056', 'c': '1.03057'}},
#   {'complete': True,
#    'volume': 88,
#    'time': '2025-01-03T20:24:00.000000000Z',
#    'mid': {'o': '1.03056', 'h': '1.03058', 'l': '1.03046', 'c': '1.03047'}},
#   {'complete': True,
#    'volume': 63,
#    'time': '2025-01-03T20:25:00.000000000Z',
#    'mid': {'o': '1.03046', 'h': '1.03052', 'l': '1.03046', 'c': '1.03052'}},
#   {'complete': True,
#    'volume': 47,
#    'time': '2025-01-03T20:26:00.000000000Z',
#    'mid': {'o': '1.03051', 'h': '1.03052', 'l': '1.03041', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2025-01-03T20:27:00.000000000Z',
#    'mid': {'o': '1.03042', 'h': '1.03045', 'l': '1.03042', 'c': '1.03042'}},
#   {'complete': True,
#    'volume': 59,
#    'time': '2025-01-03T20:28:00.000000000Z',
#    'mid': {'o': '1.03039', 'h': '1.03039', 'l': '1.03024', 'c': '1.03030'}},
#   {'complete': True,
#    'volume': 23,
#    'time': '2025-01-03T20:29:00.000000000Z',
#    'mid': {'o': '1.03031', 'h': '1.03033', 'l': '1.03029', 'c': '1.03032'}},
#   {'complete': True,
#    'volume': 53,
#    'time': '2025-01-03T20:30:00.000000000Z',
#    'mid': {'o': '1.03030', 'h': '1.03032', 'l': '1.03020', 'c': '1.03020'}},
#   {'complete': True,
#    'volume': 47,
#    'time': '2025-01-03T20:31:00.000000000Z',
#    'mid': {'o': '1.03022', 'h': '1.03032', 'l': '1.03022', 'c': '1.03031'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2025-01-03T20:32:00.000000000Z',
#    'mid': {'o': '1.03029', 'h': '1.03032', 'l': '1.03029', 'c': '1.03030'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2025-01-03T20:33:00.000000000Z',
#    'mid': {'o': '1.03032', 'h': '1.03034', 'l': '1.03031', 'c': '1.03032'}},
#   {'complete': True,
#    'volume': 56,
#    'time': '2025-01-03T20:34:00.000000000Z',
#    'mid': {'o': '1.03032', 'h': '1.03038', 'l': '1.03032', 'c': '1.03037'}},
#   {'complete': True,
#    'volume': 54,
#    'time': '2025-01-03T20:35:00.000000000Z',
#    'mid': {'o': '1.03036', 'h': '1.03038', 'l': '1.03031', 'c': '1.03035'}},
#   {'complete': True,
#    'volume': 52,
#    'time': '2025-01-03T20:36:00.000000000Z',
#    'mid': {'o': '1.03034', 'h': '1.03035', 'l': '1.03021', 'c': '1.03022'}},
#   {'complete': True,
#    'volume': 98,
#    'time': '2025-01-03T20:37:00.000000000Z',
#    'mid': {'o': '1.03022', 'h': '1.03022', 'l': '1.03011', 'c': '1.03020'}},
#   {'complete': True,
#    'volume': 74,
#    'time': '2025-01-03T20:38:00.000000000Z',
#    'mid': {'o': '1.03019', 'h': '1.03026', 'l': '1.03016', 'c': '1.03025'}},
#   {'complete': True,
#    'volume': 60,
#    'time': '2025-01-03T20:39:00.000000000Z',
#    'mid': {'o': '1.03024', 'h': '1.03025', 'l': '1.03020', 'c': '1.03025'}},
#   {'complete': True,
#    'volume': 53,
#    'time': '2025-01-03T20:40:00.000000000Z',
#    'mid': {'o': '1.03024', 'h': '1.03025', 'l': '1.03017', 'c': '1.03020'}},
#   {'complete': True,
#    'volume': 47,
#    'time': '2025-01-03T20:41:00.000000000Z',
#    'mid': {'o': '1.03018', 'h': '1.03020', 'l': '1.03014', 'c': '1.03020'}},
#   {'complete': True,
#    'volume': 37,
#    'time': '2025-01-03T20:42:00.000000000Z',
#    'mid': {'o': '1.03021', 'h': '1.03021', 'l': '1.03010', 'c': '1.03010'}},
#   {'complete': True,
#    'volume': 57,
#    'time': '2025-01-03T20:43:00.000000000Z',
#    'mid': {'o': '1.03011', 'h': '1.03016', 'l': '1.03010', 'c': '1.03015'}},
#   {'complete': True,
#    'volume': 64,
#    'time': '2025-01-03T20:44:00.000000000Z',
#    'mid': {'o': '1.03016', 'h': '1.03021', 'l': '1.03014', 'c': '1.03021'}},
#   {'complete': True,
#    'volume': 54,
#    'time': '2025-01-03T20:45:00.000000000Z',
#    'mid': {'o': '1.03020', 'h': '1.03023', 'l': '1.03016', 'c': '1.03022'}},
#   {'complete': True,
#    'volume': 61,
#    'time': '2025-01-03T20:46:00.000000000Z',
#    'mid': {'o': '1.03019', 'h': '1.03026', 'l': '1.03016', 'c': '1.03021'}},
#   {'complete': True,
#    'volume': 53,
#    'time': '2025-01-03T20:47:00.000000000Z',
#    'mid': {'o': '1.03020', 'h': '1.03029', 'l': '1.03019', 'c': '1.03028'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2025-01-03T20:48:00.000000000Z',
#    'mid': {'o': '1.03027', 'h': '1.03027', 'l': '1.03019', 'c': '1.03020'}},
#   {'complete': True,
#    'volume': 58,
#    'time': '2025-01-03T20:49:00.000000000Z',
#    'mid': {'o': '1.03019', 'h': '1.03022', 'l': '1.03014', 'c': '1.03021'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2025-01-03T20:50:00.000000000Z',
#    'mid': {'o': '1.03020', 'h': '1.03036', 'l': '1.03020', 'c': '1.03036'}},
#   {'complete': True,
#    'volume': 56,
#    'time': '2025-01-03T20:51:00.000000000Z',
#    'mid': {'o': '1.03035', 'h': '1.03052', 'l': '1.03035', 'c': '1.03050'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2025-01-03T20:52:00.000000000Z',
#    'mid': {'o': '1.03050', 'h': '1.03054', 'l': '1.03046', 'c': '1.03054'}},
#   {'complete': True,
#    'volume': 42,
#    'time': '2025-01-03T20:53:00.000000000Z',
#    'mid': {'o': '1.03057', 'h': '1.03059', 'l': '1.03051', 'c': '1.03052'}},
#   {'complete': True,
#    'volume': 101,
#    'time': '2025-01-03T20:54:00.000000000Z',
#    'mid': {'o': '1.03052', 'h': '1.03059', 'l': '1.03050', 'c': '1.03057'}},
#   {'complete': True,
#    'volume': 79,
#    'time': '2025-01-03T20:55:00.000000000Z',
#    'mid': {'o': '1.03056', 'h': '1.03064', 'l': '1.03050', 'c': '1.03054'}},
#   {'complete': True,
#    'volume': 59,
#    'time': '2025-01-03T20:56:00.000000000Z',
#    'mid': {'o': '1.03054', 'h': '1.03065', 'l': '1.03054', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 102,
#    'time': '2025-01-03T20:57:00.000000000Z',
#    'mid': {'o': '1.03061', 'h': '1.03067', 'l': '1.03053', 'c': '1.03067'}},
#   {'complete': True,
#    'volume': 74,
#    'time': '2025-01-03T20:58:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03073', 'l': '1.03062', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 78,
#    'time': '2025-01-03T20:59:00.000000000Z',
#    'mid': {'o': '1.03062', 'h': '1.03062', 'l': '1.03054', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 74,
#    'time': '2025-01-03T21:00:00.000000000Z',
#    'mid': {'o': '1.03058', 'h': '1.03058', 'l': '1.03048', 'c': '1.03052'}},
#   {'complete': True,
#    'volume': 50,
#    'time': '2025-01-03T21:01:00.000000000Z',
#    'mid': {'o': '1.03051', 'h': '1.03075', 'l': '1.03051', 'c': '1.03070'}},
#   {'complete': True,
#    'volume': 56,
#    'time': '2025-01-03T21:02:00.000000000Z',
#    'mid': {'o': '1.03070', 'h': '1.03076', 'l': '1.03066', 'c': '1.03076'}},
#   {'complete': True,
#    'volume': 60,
#    'time': '2025-01-03T21:03:00.000000000Z',
#    'mid': {'o': '1.03077', 'h': '1.03083', 'l': '1.03074', 'c': '1.03079'}},
#   {'complete': True,
#    'volume': 43,
#    'time': '2025-01-03T21:04:00.000000000Z',
#    'mid': {'o': '1.03078', 'h': '1.03084', 'l': '1.03076', 'c': '1.03080'}},
#   {'complete': True,
#    'volume': 56,
#    'time': '2025-01-03T21:05:00.000000000Z',
#    'mid': {'o': '1.03080', 'h': '1.03092', 'l': '1.03080', 'c': '1.03092'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2025-01-03T21:06:00.000000000Z',
#    'mid': {'o': '1.03093', 'h': '1.03094', 'l': '1.03088', 'c': '1.03093'}},
#   {'complete': True,
#    'volume': 37,
#    'time': '2025-01-03T21:07:00.000000000Z',
#    'mid': {'o': '1.03094', 'h': '1.03099', 'l': '1.03090', 'c': '1.03090'}},
#   {'complete': True,
#    'volume': 37,
#    'time': '2025-01-03T21:08:00.000000000Z',
#    'mid': {'o': '1.03091', 'h': '1.03094', 'l': '1.03084', 'c': '1.03094'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2025-01-03T21:09:00.000000000Z',
#    'mid': {'o': '1.03097', 'h': '1.03100', 'l': '1.03096', 'c': '1.03099'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2025-01-03T21:10:00.000000000Z',
#    'mid': {'o': '1.03098', 'h': '1.03098', 'l': '1.03094', 'c': '1.03094'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2025-01-03T21:11:00.000000000Z',
#    'mid': {'o': '1.03094', 'h': '1.03094', 'l': '1.03091', 'c': '1.03091'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2025-01-03T21:13:00.000000000Z',
#    'mid': {'o': '1.03089', 'h': '1.03089', 'l': '1.03077', 'c': '1.03077'}},
#   {'complete': True,
#    'volume': 45,
#    'time': '2025-01-03T21:14:00.000000000Z',
#    'mid': {'o': '1.03078', 'h': '1.03080', 'l': '1.03072', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2025-01-03T21:15:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03072', 'l': '1.03070', 'c': '1.03070'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2025-01-03T21:16:00.000000000Z',
#    'mid': {'o': '1.03070', 'h': '1.03072', 'l': '1.03068', 'c': '1.03068'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2025-01-03T21:17:00.000000000Z',
#    'mid': {'o': '1.03069', 'h': '1.03070', 'l': '1.03068', 'c': '1.03069'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2025-01-03T21:18:00.000000000Z',
#    'mid': {'o': '1.03067', 'h': '1.03071', 'l': '1.03066', 'c': '1.03070'}},
#   {'complete': True,
#    'volume': 24,
#    'time': '2025-01-03T21:19:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03073', 'l': '1.03068', 'c': '1.03068'}},
#   {'complete': True,
#    'volume': 42,
#    'time': '2025-01-03T21:20:00.000000000Z',
#    'mid': {'o': '1.03068', 'h': '1.03078', 'l': '1.03068', 'c': '1.03076'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2025-01-03T21:21:00.000000000Z',
#    'mid': {'o': '1.03076', 'h': '1.03078', 'l': '1.03076', 'c': '1.03077'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2025-01-03T21:22:00.000000000Z',
#    'mid': {'o': '1.03076', 'h': '1.03077', 'l': '1.03076', 'c': '1.03076'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2025-01-03T21:23:00.000000000Z',
#    'mid': {'o': '1.03077', 'h': '1.03077', 'l': '1.03072', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2025-01-03T21:24:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03072', 'l': '1.03067', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2025-01-03T21:25:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03072', 'l': '1.03072', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2025-01-03T21:26:00.000000000Z',
#    'mid': {'o': '1.03070', 'h': '1.03070', 'l': '1.03068', 'c': '1.03070'}},
#   {'complete': True,
#    'volume': 15,
#    'time': '2025-01-03T21:27:00.000000000Z',
#    'mid': {'o': '1.03070', 'h': '1.03074', 'l': '1.03070', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2025-01-03T21:28:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03073', 'l': '1.03072', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 62,
#    'time': '2025-01-03T21:29:00.000000000Z',
#    'mid': {'o': '1.03071', 'h': '1.03080', 'l': '1.03068', 'c': '1.03078'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2025-01-03T21:30:00.000000000Z',
#    'mid': {'o': '1.03080', 'h': '1.03080', 'l': '1.03072', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2025-01-03T21:31:00.000000000Z',
#    'mid': {'o': '1.03069', 'h': '1.03075', 'l': '1.03069', 'c': '1.03075'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2025-01-03T21:32:00.000000000Z',
#    'mid': {'o': '1.03079', 'h': '1.03079', 'l': '1.03076', 'c': '1.03076'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2025-01-03T21:33:00.000000000Z',
#    'mid': {'o': '1.03077', 'h': '1.03080', 'l': '1.03076', 'c': '1.03080'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2025-01-03T21:34:00.000000000Z',
#    'mid': {'o': '1.03078', 'h': '1.03078', 'l': '1.03074', 'c': '1.03075'}},
#   {'complete': True,
#    'volume': 7,
#    'time': '2025-01-03T21:35:00.000000000Z',
#    'mid': {'o': '1.03074', 'h': '1.03074', 'l': '1.03067', 'c': '1.03067'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2025-01-03T21:36:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03066', 'l': '1.03065', 'c': '1.03066'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2025-01-03T21:37:00.000000000Z',
#    'mid': {'o': '1.03065', 'h': '1.03065', 'l': '1.03064', 'c': '1.03064'}},
#   {'complete': True,
#    'volume': 29,
#    'time': '2025-01-03T21:38:00.000000000Z',
#    'mid': {'o': '1.03065', 'h': '1.03065', 'l': '1.03062', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-03T21:39:00.000000000Z',
#    'mid': {'o': '1.03062', 'h': '1.03064', 'l': '1.03061', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 4,
#    'time': '2025-01-03T21:40:00.000000000Z',
#    'mid': {'o': '1.03063', 'h': '1.03063', 'l': '1.03062', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2025-01-03T21:41:00.000000000Z',
#    'mid': {'o': '1.03060', 'h': '1.03062', 'l': '1.03060', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2025-01-03T21:42:00.000000000Z',
#    'mid': {'o': '1.03062', 'h': '1.03062', 'l': '1.03060', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 61,
#    'time': '2025-01-03T21:43:00.000000000Z',
#    'mid': {'o': '1.03060', 'h': '1.03070', 'l': '1.03060', 'c': '1.03066'}},
#   {'complete': True,
#    'volume': 35,
#    'time': '2025-01-03T21:44:00.000000000Z',
#    'mid': {'o': '1.03069', 'h': '1.03074', 'l': '1.03068', 'c': '1.03073'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2025-01-03T21:45:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03082', 'l': '1.03072', 'c': '1.03073'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2025-01-03T21:46:00.000000000Z',
#    'mid': {'o': '1.03074', 'h': '1.03074', 'l': '1.03073', 'c': '1.03074'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2025-01-03T21:47:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03073', 'l': '1.03068', 'c': '1.03071'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2025-01-03T21:48:00.000000000Z',
#    'mid': {'o': '1.03071', 'h': '1.03079', 'l': '1.03071', 'c': '1.03079'}},
#   {'complete': True,
#    'volume': 48,
#    'time': '2025-01-03T21:49:00.000000000Z',
#    'mid': {'o': '1.03078', 'h': '1.03082', 'l': '1.03077', 'c': '1.03080'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2025-01-03T21:50:00.000000000Z',
#    'mid': {'o': '1.03078', 'h': '1.03078', 'l': '1.03076', 'c': '1.03077'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2025-01-03T21:51:00.000000000Z',
#    'mid': {'o': '1.03076', 'h': '1.03080', 'l': '1.03076', 'c': '1.03078'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2025-01-03T21:52:00.000000000Z',
#    'mid': {'o': '1.03078', 'h': '1.03080', 'l': '1.03078', 'c': '1.03080'}},
#   {'complete': True,
#    'volume': 35,
#    'time': '2025-01-03T21:53:00.000000000Z',
#    'mid': {'o': '1.03079', 'h': '1.03084', 'l': '1.03078', 'c': '1.03081'}},
#   {'complete': True,
#    'volume': 17,
#    'time': '2025-01-03T21:54:00.000000000Z',
#    'mid': {'o': '1.03082', 'h': '1.03082', 'l': '1.03079', 'c': '1.03081'}},
#   {'complete': True,
#    'volume': 36,
#    'time': '2025-01-03T21:55:00.000000000Z',
#    'mid': {'o': '1.03080', 'h': '1.03085', 'l': '1.03080', 'c': '1.03082'}},
#   {'complete': True,
#    'volume': 68,
#    'time': '2025-01-03T21:56:00.000000000Z',
#    'mid': {'o': '1.03082', 'h': '1.03094', 'l': '1.03082', 'c': '1.03085'}},
#   {'complete': True,
#    'volume': 23,
#    'time': '2025-01-03T21:57:00.000000000Z',
#    'mid': {'o': '1.03086', 'h': '1.03087', 'l': '1.03084', 'c': '1.03087'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2025-01-03T21:58:00.000000000Z',
#    'mid': {'o': '1.03088', 'h': '1.03092', 'l': '1.03086', 'c': '1.03089'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-03T21:59:00.000000000Z',
#    'mid': {'o': '1.03088', 'h': '1.03092', 'l': '1.03086', 'c': '1.03090'}},
#   {'complete': True,
#    'volume': 1,
#    'time': '2025-01-05T22:04:00.000000000Z',
#    'mid': {'o': '1.03057', 'h': '1.03057', 'l': '1.03057', 'c': '1.03057'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2025-01-05T22:05:00.000000000Z',
#    'mid': {'o': '1.03057', 'h': '1.03065', 'l': '1.03048', 'c': '1.03048'}},
#   {'complete': True,
#    'volume': 3,
#    'time': '2025-01-05T22:06:00.000000000Z',
#    'mid': {'o': '1.03052', 'h': '1.03052', 'l': '1.03051', 'c': '1.03051'}},
#   {'complete': True,
#    'volume': 4,
#    'time': '2025-01-05T22:08:00.000000000Z',
#    'mid': {'o': '1.03053', 'h': '1.03055', 'l': '1.03050', 'c': '1.03050'}},
#   {'complete': True,
#    'volume': 3,
#    'time': '2025-01-05T22:09:00.000000000Z',
#    'mid': {'o': '1.03048', 'h': '1.03049', 'l': '1.03048', 'c': '1.03049'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2025-01-05T22:10:00.000000000Z',
#    'mid': {'o': '1.03050', 'h': '1.03050', 'l': '1.03050', 'c': '1.03050'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2025-01-05T22:11:00.000000000Z',
#    'mid': {'o': '1.03050', 'h': '1.03050', 'l': '1.03042', 'c': '1.03042'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2025-01-05T22:12:00.000000000Z',
#    'mid': {'o': '1.03044', 'h': '1.03044', 'l': '1.03043', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2025-01-05T22:13:00.000000000Z',
#    'mid': {'o': '1.03043', 'h': '1.03044', 'l': '1.03042', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2025-01-05T22:14:00.000000000Z',
#    'mid': {'o': '1.03043', 'h': '1.03044', 'l': '1.03042', 'c': '1.03042'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2025-01-05T22:16:00.000000000Z',
#    'mid': {'o': '1.03037', 'h': '1.03042', 'l': '1.03037', 'c': '1.03042'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2025-01-05T22:17:00.000000000Z',
#    'mid': {'o': '1.03040', 'h': '1.03044', 'l': '1.03040', 'c': '1.03042'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2025-01-05T22:18:00.000000000Z',
#    'mid': {'o': '1.03042', 'h': '1.03044', 'l': '1.03041', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 3,
#    'time': '2025-01-05T22:19:00.000000000Z',
#    'mid': {'o': '1.03042', 'h': '1.03044', 'l': '1.03042', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2025-01-05T22:20:00.000000000Z',
#    'mid': {'o': '1.03043', 'h': '1.03044', 'l': '1.03043', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 3,
#    'time': '2025-01-05T22:21:00.000000000Z',
#    'mid': {'o': '1.03044', 'h': '1.03046', 'l': '1.03044', 'c': '1.03045'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2025-01-05T22:22:00.000000000Z',
#    'mid': {'o': '1.03046', 'h': '1.03046', 'l': '1.03045', 'c': '1.03046'}},
#   {'complete': True,
#    'volume': 4,
#    'time': '2025-01-05T22:23:00.000000000Z',
#    'mid': {'o': '1.03046', 'h': '1.03064', 'l': '1.03046', 'c': '1.03064'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-05T22:24:00.000000000Z',
#    'mid': {'o': '1.03064', 'h': '1.03065', 'l': '1.03063', 'c': '1.03064'}},
#   {'complete': True,
#    'volume': 2,
#    'time': '2025-01-05T22:25:00.000000000Z',
#    'mid': {'o': '1.03064', 'h': '1.03065', 'l': '1.03064', 'c': '1.03065'}},
#   {'complete': True,
#    'volume': 15,
#    'time': '2025-01-05T22:26:00.000000000Z',
#    'mid': {'o': '1.03064', 'h': '1.03066', 'l': '1.03064', 'c': '1.03065'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-05T22:27:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03066', 'l': '1.03056', 'c': '1.03063'}},
#   {'complete': True,
#    'volume': 1,
#    'time': '2025-01-05T22:28:00.000000000Z',
#    'mid': {'o': '1.03062', 'h': '1.03062', 'l': '1.03062', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2025-01-05T22:29:00.000000000Z',
#    'mid': {'o': '1.03063', 'h': '1.03069', 'l': '1.03062', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 4,
#    'time': '2025-01-05T22:30:00.000000000Z',
#    'mid': {'o': '1.03062', 'h': '1.03062', 'l': '1.03060', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2025-01-05T22:31:00.000000000Z',
#    'mid': {'o': '1.03061', 'h': '1.03063', 'l': '1.03051', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 4,
#    'time': '2025-01-05T22:32:00.000000000Z',
#    'mid': {'o': '1.03064', 'h': '1.03064', 'l': '1.03062', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2025-01-05T22:33:00.000000000Z',
#    'mid': {'o': '1.03061', 'h': '1.03068', 'l': '1.03061', 'c': '1.03066'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-05T22:34:00.000000000Z',
#    'mid': {'o': '1.03068', 'h': '1.03068', 'l': '1.03066', 'c': '1.03066'}},
#   {'complete': True,
#    'volume': 24,
#    'time': '2025-01-05T22:35:00.000000000Z',
#    'mid': {'o': '1.03068', 'h': '1.03072', 'l': '1.03064', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-05T22:36:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03074', 'l': '1.03072', 'c': '1.03074'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2025-01-05T22:37:00.000000000Z',
#    'mid': {'o': '1.03073', 'h': '1.03074', 'l': '1.03072', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2025-01-05T22:38:00.000000000Z',
#    'mid': {'o': '1.03073', 'h': '1.03073', 'l': '1.03070', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2025-01-05T22:39:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03072', 'l': '1.03070', 'c': '1.03070'}},
#   {'complete': True,
#    'volume': 3,
#    'time': '2025-01-05T22:40:00.000000000Z',
#    'mid': {'o': '1.03071', 'h': '1.03071', 'l': '1.03070', 'c': '1.03071'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2025-01-05T22:41:00.000000000Z',
#    'mid': {'o': '1.03070', 'h': '1.03071', 'l': '1.03069', 'c': '1.03069'}},
#   {'complete': True,
#    'volume': 3,
#    'time': '2025-01-05T22:42:00.000000000Z',
#    'mid': {'o': '1.03070', 'h': '1.03070', 'l': '1.03069', 'c': '1.03070'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2025-01-05T22:43:00.000000000Z',
#    'mid': {'o': '1.03068', 'h': '1.03070', 'l': '1.03066', 'c': '1.03066'}},
#   {'complete': True,
#    'volume': 15,
#    'time': '2025-01-05T22:44:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03068', 'l': '1.03066', 'c': '1.03067'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2025-01-05T22:45:00.000000000Z',
#    'mid': {'o': '1.03068', 'h': '1.03068', 'l': '1.03066', 'c': '1.03068'}},
#   {'complete': True,
#    'volume': 23,
#    'time': '2025-01-05T22:46:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03070', 'l': '1.03066', 'c': '1.03068'}},
#   {'complete': True,
#    'volume': 48,
#    'time': '2025-01-05T22:47:00.000000000Z',
#    'mid': {'o': '1.03070', 'h': '1.03070', 'l': '1.03064', 'c': '1.03067'}},
#   {'complete': True,
#    'volume': 24,
#    'time': '2025-01-05T22:48:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03070', 'l': '1.03066', 'c': '1.03067'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2025-01-05T22:49:00.000000000Z',
#    'mid': {'o': '1.03068', 'h': '1.03068', 'l': '1.03064', 'c': '1.03066'}},
#   {'complete': True,
#    'volume': 20,
#    'time': '2025-01-05T22:50:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03067', 'l': '1.03066', 'c': '1.03066'}},
#   {'complete': True,
#    'volume': 17,
#    'time': '2025-01-05T22:51:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03066', 'l': '1.03053', 'c': '1.03053'}},
#   {'complete': True,
#    'volume': 41,
#    'time': '2025-01-05T22:52:00.000000000Z',
#    'mid': {'o': '1.03048', 'h': '1.03052', 'l': '1.03016', 'c': '1.03020'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2025-01-05T22:53:00.000000000Z',
#    'mid': {'o': '1.03019', 'h': '1.03022', 'l': '1.03018', 'c': '1.03020'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-05T22:54:00.000000000Z',
#    'mid': {'o': '1.03021', 'h': '1.03023', 'l': '1.03021', 'c': '1.03022'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-05T22:55:00.000000000Z',
#    'mid': {'o': '1.03022', 'h': '1.03026', 'l': '1.03022', 'c': '1.03026'}},
#   {'complete': True,
#    'volume': 143,
#    'time': '2025-01-05T22:56:00.000000000Z',
#    'mid': {'o': '1.03026', 'h': '1.03026', 'l': '1.02973', 'c': '1.03006'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2025-01-05T22:57:00.000000000Z',
#    'mid': {'o': '1.03006', 'h': '1.03008', 'l': '1.03000', 'c': '1.03002'}},
#   {'complete': True,
#    'volume': 41,
#    'time': '2025-01-05T22:58:00.000000000Z',
#    'mid': {'o': '1.03002', 'h': '1.03023', 'l': '1.03002', 'c': '1.03012'}},
#   {'complete': True,
#    'volume': 69,
#    'time': '2025-01-05T22:59:00.000000000Z',
#    'mid': {'o': '1.03018', 'h': '1.03023', 'l': '1.03017', 'c': '1.03022'}},
#   {'complete': True,
#    'volume': 157,
#    'time': '2025-01-05T23:00:00.000000000Z',
#    'mid': {'o': '1.03022', 'h': '1.03072', 'l': '1.03015', 'c': '1.03020'}},
#   {'complete': True,
#    'volume': 39,
#    'time': '2025-01-05T23:01:00.000000000Z',
#    'mid': {'o': '1.03020', 'h': '1.03035', 'l': '1.03020', 'c': '1.03034'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2025-01-05T23:02:00.000000000Z',
#    'mid': {'o': '1.03036', 'h': '1.03036', 'l': '1.03028', 'c': '1.03028'}},
#   {'complete': True,
#    'volume': 29,
#    'time': '2025-01-05T23:03:00.000000000Z',
#    'mid': {'o': '1.03028', 'h': '1.03034', 'l': '1.03028', 'c': '1.03032'}},
#   {'complete': True,
#    'volume': 35,
#    'time': '2025-01-05T23:04:00.000000000Z',
#    'mid': {'o': '1.03032', 'h': '1.03043', 'l': '1.03032', 'c': '1.03042'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2025-01-05T23:05:00.000000000Z',
#    'mid': {'o': '1.03042', 'h': '1.03043', 'l': '1.03033', 'c': '1.03033'}},
#   {'complete': True,
#    'volume': 29,
#    'time': '2025-01-05T23:06:00.000000000Z',
#    'mid': {'o': '1.03034', 'h': '1.03050', 'l': '1.03034', 'c': '1.03043'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2025-01-05T23:07:00.000000000Z',
#    'mid': {'o': '1.03044', 'h': '1.03045', 'l': '1.03043', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 39,
#    'time': '2025-01-05T23:08:00.000000000Z',
#    'mid': {'o': '1.03043', 'h': '1.03043', 'l': '1.03028', 'c': '1.03032'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2025-01-05T23:09:00.000000000Z',
#    'mid': {'o': '1.03034', 'h': '1.03042', 'l': '1.03032', 'c': '1.03042'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2025-01-05T23:10:00.000000000Z',
#    'mid': {'o': '1.03040', 'h': '1.03042', 'l': '1.03038', 'c': '1.03038'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2025-01-05T23:11:00.000000000Z',
#    'mid': {'o': '1.03034', 'h': '1.03042', 'l': '1.03030', 'c': '1.03039'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2025-01-05T23:12:00.000000000Z',
#    'mid': {'o': '1.03040', 'h': '1.03042', 'l': '1.03031', 'c': '1.03040'}},
#   {'complete': True,
#    'volume': 66,
#    'time': '2025-01-05T23:13:00.000000000Z',
#    'mid': {'o': '1.03038', 'h': '1.03056', 'l': '1.03038', 'c': '1.03047'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2025-01-05T23:14:00.000000000Z',
#    'mid': {'o': '1.03046', 'h': '1.03056', 'l': '1.03046', 'c': '1.03053'}},
#   {'complete': True,
#    'volume': 56,
#    'time': '2025-01-05T23:15:00.000000000Z',
#    'mid': {'o': '1.03052', 'h': '1.03060', 'l': '1.03048', 'c': '1.03058'}},
#   {'complete': True,
#    'volume': 17,
#    'time': '2025-01-05T23:16:00.000000000Z',
#    'mid': {'o': '1.03058', 'h': '1.03060', 'l': '1.03058', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2025-01-05T23:17:00.000000000Z',
#    'mid': {'o': '1.03062', 'h': '1.03066', 'l': '1.03058', 'c': '1.03058'}},
#   {'complete': True,
#    'volume': 17,
#    'time': '2025-01-05T23:18:00.000000000Z',
#    'mid': {'o': '1.03058', 'h': '1.03060', 'l': '1.03058', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2025-01-05T23:19:00.000000000Z',
#    'mid': {'o': '1.03063', 'h': '1.03065', 'l': '1.03060', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2025-01-05T23:20:00.000000000Z',
#    'mid': {'o': '1.03058', 'h': '1.03060', 'l': '1.03058', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2025-01-05T23:21:00.000000000Z',
#    'mid': {'o': '1.03059', 'h': '1.03060', 'l': '1.03052', 'c': '1.03052'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2025-01-05T23:22:00.000000000Z',
#    'mid': {'o': '1.03050', 'h': '1.03059', 'l': '1.03046', 'c': '1.03056'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2025-01-05T23:23:00.000000000Z',
#    'mid': {'o': '1.03054', 'h': '1.03056', 'l': '1.03054', 'c': '1.03056'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-05T23:24:00.000000000Z',
#    'mid': {'o': '1.03054', 'h': '1.03056', 'l': '1.03054', 'c': '1.03056'}},
#   {'complete': True,
#    'volume': 15,
#    'time': '2025-01-05T23:25:00.000000000Z',
#    'mid': {'o': '1.03056', 'h': '1.03056', 'l': '1.03056', 'c': '1.03056'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2025-01-05T23:26:00.000000000Z',
#    'mid': {'o': '1.03056', 'h': '1.03059', 'l': '1.03055', 'c': '1.03058'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2025-01-05T23:27:00.000000000Z',
#    'mid': {'o': '1.03056', 'h': '1.03059', 'l': '1.03054', 'c': '1.03058'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2025-01-05T23:28:00.000000000Z',
#    'mid': {'o': '1.03058', 'h': '1.03058', 'l': '1.03055', 'c': '1.03056'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-05T23:29:00.000000000Z',
#    'mid': {'o': '1.03056', 'h': '1.03056', 'l': '1.03056', 'c': '1.03056'}},
#   {'complete': True,
#    'volume': 47,
#    'time': '2025-01-05T23:30:00.000000000Z',
#    'mid': {'o': '1.03052', 'h': '1.03066', 'l': '1.03049', 'c': '1.03064'}},
#   {'complete': True,
#    'volume': 35,
#    'time': '2025-01-05T23:31:00.000000000Z',
#    'mid': {'o': '1.03062', 'h': '1.03062', 'l': '1.03049', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 29,
#    'time': '2025-01-05T23:32:00.000000000Z',
#    'mid': {'o': '1.03059', 'h': '1.03059', 'l': '1.03050', 'c': '1.03050'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2025-01-05T23:33:00.000000000Z',
#    'mid': {'o': '1.03049', 'h': '1.03056', 'l': '1.03043', 'c': '1.03046'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2025-01-05T23:34:00.000000000Z',
#    'mid': {'o': '1.03045', 'h': '1.03049', 'l': '1.03044', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2025-01-05T23:35:00.000000000Z',
#    'mid': {'o': '1.03045', 'h': '1.03045', 'l': '1.03036', 'c': '1.03036'}},
#   {'complete': True,
#    'volume': 17,
#    'time': '2025-01-05T23:36:00.000000000Z',
#    'mid': {'o': '1.03036', 'h': '1.03044', 'l': '1.03036', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2025-01-05T23:37:00.000000000Z',
#    'mid': {'o': '1.03042', 'h': '1.03044', 'l': '1.03041', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2025-01-05T23:38:00.000000000Z',
#    'mid': {'o': '1.03044', 'h': '1.03052', 'l': '1.03044', 'c': '1.03051'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2025-01-05T23:39:00.000000000Z',
#    'mid': {'o': '1.03050', 'h': '1.03052', 'l': '1.03050', 'c': '1.03050'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2025-01-05T23:40:00.000000000Z',
#    'mid': {'o': '1.03052', 'h': '1.03060', 'l': '1.03052', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 28,
#    'time': '2025-01-05T23:41:00.000000000Z',
#    'mid': {'o': '1.03060', 'h': '1.03070', 'l': '1.03060', 'c': '1.03065'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2025-01-05T23:42:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03066', 'l': '1.03064', 'c': '1.03066'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2025-01-05T23:43:00.000000000Z',
#    'mid': {'o': '1.03067', 'h': '1.03070', 'l': '1.03067', 'c': '1.03070'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2025-01-05T23:44:00.000000000Z',
#    'mid': {'o': '1.03070', 'h': '1.03073', 'l': '1.03070', 'c': '1.03071'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2025-01-05T23:45:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03074', 'l': '1.03070', 'c': '1.03071'}},
#   {'complete': True,
#    'volume': 39,
#    'time': '2025-01-05T23:46:00.000000000Z',
#    'mid': {'o': '1.03072', 'h': '1.03078', 'l': '1.03066', 'c': '1.03078'}},
#   {'complete': True,
#    'volume': 31,
#    'time': '2025-01-05T23:47:00.000000000Z',
#    'mid': {'o': '1.03079', 'h': '1.03080', 'l': '1.03075', 'c': '1.03079'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2025-01-05T23:48:00.000000000Z',
#    'mid': {'o': '1.03080', 'h': '1.03080', 'l': '1.03079', 'c': '1.03080'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2025-01-05T23:49:00.000000000Z',
#    'mid': {'o': '1.03080', 'h': '1.03080', 'l': '1.03076', 'c': '1.03078'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2025-01-05T23:50:00.000000000Z',
#    'mid': {'o': '1.03076', 'h': '1.03076', 'l': '1.03072', 'c': '1.03076'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2025-01-05T23:51:00.000000000Z',
#    'mid': {'o': '1.03074', 'h': '1.03075', 'l': '1.03060', 'c': '1.03060'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2025-01-05T23:52:00.000000000Z',
#    'mid': {'o': '1.03060', 'h': '1.03063', 'l': '1.03056', 'c': '1.03056'}},
#   {'complete': True,
#    'volume': 28,
#    'time': '2025-01-05T23:53:00.000000000Z',
#    'mid': {'o': '1.03054', 'h': '1.03056', 'l': '1.03046', 'c': '1.03047'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2025-01-05T23:54:00.000000000Z',
#    'mid': {'o': '1.03046', 'h': '1.03050', 'l': '1.03045', 'c': '1.03049'}},
#   {'complete': True,
#    'volume': 36,
#    'time': '2025-01-05T23:55:00.000000000Z',
#    'mid': {'o': '1.03048', 'h': '1.03048', 'l': '1.03042', 'c': '1.03048'}},
#   {'complete': True,
#    'volume': 45,
#    'time': '2025-01-05T23:56:00.000000000Z',
#    'mid': {'o': '1.03048', 'h': '1.03052', 'l': '1.03041', 'c': '1.03050'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2025-01-05T23:57:00.000000000Z',
#    'mid': {'o': '1.03050', 'h': '1.03052', 'l': '1.03046', 'c': '1.03050'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2025-01-05T23:58:00.000000000Z',
#    'mid': {'o': '1.03049', 'h': '1.03052', 'l': '1.03045', 'c': '1.03050'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2025-01-05T23:59:00.000000000Z',
#    'mid': {'o': '1.03048', 'h': '1.03053', 'l': '1.03045', 'c': '1.03052'}},
#   {'complete': True,
#    'volume': 79,
#    'time': '2025-01-06T00:00:00.000000000Z',
#    'mid': {'o': '1.03054', 'h': '1.03054', 'l': '1.03028', 'c': '1.03028'}},
#   {'complete': True,
#    'volume': 60,
#    'time': '2025-01-06T00:01:00.000000000Z',
#    'mid': {'o': '1.03028', 'h': '1.03044', 'l': '1.03026', 'c': '1.03040'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2025-01-06T00:02:00.000000000Z',
#    'mid': {'o': '1.03039', 'h': '1.03040', 'l': '1.03030', 'c': '1.03030'}},
#   {'complete': True,
#    'volume': 59,
#    'time': '2025-01-06T00:03:00.000000000Z',
#    'mid': {'o': '1.03032', 'h': '1.03033', 'l': '1.03026', 'c': '1.03026'}},
#   {'complete': True,
#    'volume': 41,
#    'time': '2025-01-06T00:04:00.000000000Z',
#    'mid': {'o': '1.03027', 'h': '1.03030', 'l': '1.03016', 'c': '1.03023'}},
#   {'complete': True,
#    'volume': 59,
#    'time': '2025-01-06T00:05:00.000000000Z',
#    'mid': {'o': '1.03022', 'h': '1.03025', 'l': '1.03010', 'c': '1.03016'}},
#   {'complete': True,
#    'volume': 68,
#    'time': '2025-01-06T00:06:00.000000000Z',
#    'mid': {'o': '1.03015', 'h': '1.03015', 'l': '1.03006', 'c': '1.03006'}},
#   {'complete': True,
#    'volume': 88,
#    'time': '2025-01-06T00:07:00.000000000Z',
#    'mid': {'o': '1.03007', 'h': '1.03008', 'l': '1.02990', 'c': '1.02991'}},
#   {'complete': True,
#    'volume': 65,
#    'time': '2025-01-06T00:08:00.000000000Z',
#    'mid': {'o': '1.02992', 'h': '1.02995', 'l': '1.02990', 'c': '1.02992'}},
#   {'complete': True,
#    'volume': 95,
#    'time': '2025-01-06T00:09:00.000000000Z',
#    'mid': {'o': '1.02992', 'h': '1.02992', 'l': '1.02978', 'c': '1.02987'}},
#   {'complete': True,
#    'volume': 50,
#    'time': '2025-01-06T00:10:00.000000000Z',
#    'mid': {'o': '1.02988', 'h': '1.02993', 'l': '1.02974', 'c': '1.02974'}},
#   {'complete': True,
#    'volume': 108,
#    'time': '2025-01-06T00:11:00.000000000Z',
#    'mid': {'o': '1.02977', 'h': '1.02980', 'l': '1.02967', 'c': '1.02968'}},
#   {'complete': True,
#    'volume': 94,
#    'time': '2025-01-06T00:12:00.000000000Z',
#    'mid': {'o': '1.02967', 'h': '1.02967', 'l': '1.02958', 'c': '1.02962'}},
#   {'complete': True,
#    'volume': 52,
#    'time': '2025-01-06T00:13:00.000000000Z',
#    'mid': {'o': '1.02963', 'h': '1.02971', 'l': '1.02961', 'c': '1.02967'}},
#   {'complete': True,
#    'volume': 61,
#    'time': '2025-01-06T00:14:00.000000000Z',
#    'mid': {'o': '1.02968', 'h': '1.02970', 'l': '1.02964', 'c': '1.02967'}},
#   {'complete': True,
#    'volume': 118,
#    'time': '2025-01-06T00:15:00.000000000Z',
#    'mid': {'o': '1.02966', 'h': '1.02992', 'l': '1.02964', 'c': '1.02988'}},
#   {'complete': True,
#    'volume': 77,
#    'time': '2025-01-06T00:16:00.000000000Z',
#    'mid': {'o': '1.02990', 'h': '1.03003', 'l': '1.02990', 'c': '1.02994'}},
#   {'complete': True,
#    'volume': 84,
#    'time': '2025-01-06T00:17:00.000000000Z',
#    'mid': {'o': '1.02994', 'h': '1.02997', 'l': '1.02983', 'c': '1.02992'}},
#   {'complete': True,
#    'volume': 47,
#    'time': '2025-01-06T00:18:00.000000000Z',
#    'mid': {'o': '1.02991', 'h': '1.02994', 'l': '1.02988', 'c': '1.02989'}},
#   {'complete': True,
#    'volume': 60,
#    'time': '2025-01-06T00:19:00.000000000Z',
#    'mid': {'o': '1.02988', 'h': '1.02990', 'l': '1.02982', 'c': '1.02986'}},
#   {'complete': True,
#    'volume': 37,
#    'time': '2025-01-06T00:20:00.000000000Z',
#    'mid': {'o': '1.02987', 'h': '1.02987', 'l': '1.02976', 'c': '1.02976'}},
#   {'complete': True,
#    'volume': 36,
#    'time': '2025-01-06T00:21:00.000000000Z',
#    'mid': {'o': '1.02978', 'h': '1.02978', 'l': '1.02969', 'c': '1.02970'}},
#   {'complete': True,
#    'volume': 53,
#    'time': '2025-01-06T00:22:00.000000000Z',
#    'mid': {'o': '1.02970', 'h': '1.02972', 'l': '1.02964', 'c': '1.02968'}},
#   {'complete': True,
#    'volume': 45,
#    'time': '2025-01-06T00:23:00.000000000Z',
#    'mid': {'o': '1.02968', 'h': '1.02973', 'l': '1.02964', 'c': '1.02973'}},
#   {'complete': True,
#    'volume': 52,
#    'time': '2025-01-06T00:24:00.000000000Z',
#    'mid': {'o': '1.02972', 'h': '1.02984', 'l': '1.02971', 'c': '1.02981'}},
#   {'complete': True,
#    'volume': 68,
#    'time': '2025-01-06T00:25:00.000000000Z',
#    'mid': {'o': '1.02980', 'h': '1.02984', 'l': '1.02972', 'c': '1.02979'}},
#   {'complete': True,
#    'volume': 43,
#    'time': '2025-01-06T00:26:00.000000000Z',
#    'mid': {'o': '1.02978', 'h': '1.02978', 'l': '1.02972', 'c': '1.02974'}},
#   {'complete': True,
#    'volume': 50,
#    'time': '2025-01-06T00:27:00.000000000Z',
#    'mid': {'o': '1.02976', 'h': '1.02978', 'l': '1.02970', 'c': '1.02974'}},
#   {'complete': True,
#    'volume': 42,
#    'time': '2025-01-06T00:28:00.000000000Z',
#    'mid': {'o': '1.02974', 'h': '1.02974', 'l': '1.02970', 'c': '1.02972'}},
#   {'complete': True,
#    'volume': 58,
#    'time': '2025-01-06T00:29:00.000000000Z',
#    'mid': {'o': '1.02972', 'h': '1.02974', 'l': '1.02969', 'c': '1.02974'}},
#   {'complete': True,
#    'volume': 70,
#    'time': '2025-01-06T00:30:00.000000000Z',
#    'mid': {'o': '1.02974', 'h': '1.02977', 'l': '1.02965', 'c': '1.02969'}},
#   {'complete': True,
#    'volume': 75,
#    'time': '2025-01-06T00:31:00.000000000Z',
#    'mid': {'o': '1.02968', 'h': '1.02972', 'l': '1.02966', 'c': '1.02970'}},
#   {'complete': True,
#    'volume': 104,
#    'time': '2025-01-06T00:32:00.000000000Z',
#    'mid': {'o': '1.02968', 'h': '1.02970', 'l': '1.02960', 'c': '1.02964'}},
#   {'complete': True,
#    'volume': 106,
#    'time': '2025-01-06T00:33:00.000000000Z',
#    'mid': {'o': '1.02964', 'h': '1.02966', 'l': '1.02958', 'c': '1.02962'}},
#   {'complete': True,
#    'volume': 63,
#    'time': '2025-01-06T00:34:00.000000000Z',
#    'mid': {'o': '1.02962', 'h': '1.02968', 'l': '1.02958', 'c': '1.02966'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2025-01-06T00:35:00.000000000Z',
#    'mid': {'o': '1.02964', 'h': '1.02972', 'l': '1.02964', 'c': '1.02964'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2025-01-06T00:36:00.000000000Z',
#    'mid': {'o': '1.02964', 'h': '1.02968', 'l': '1.02964', 'c': '1.02967'}},
#   {'complete': True,
#    'volume': 46,
#    'time': '2025-01-06T00:37:00.000000000Z',
#    'mid': {'o': '1.02968', 'h': '1.02968', 'l': '1.02958', 'c': '1.02964'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2025-01-06T00:38:00.000000000Z',
#    'mid': {'o': '1.02964', 'h': '1.02964', 'l': '1.02960', 'c': '1.02960'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2025-01-06T00:39:00.000000000Z',
#    'mid': {'o': '1.02962', 'h': '1.02962', 'l': '1.02957', 'c': '1.02958'}},
#   {'complete': True,
#    'volume': 32,
#    'time': '2025-01-06T00:40:00.000000000Z',
#    'mid': {'o': '1.02960', 'h': '1.02960', 'l': '1.02956', 'c': '1.02956'}},
#   {'complete': True,
#    'volume': 50,
#    'time': '2025-01-06T00:41:00.000000000Z',
#    'mid': {'o': '1.02959', 'h': '1.02974', 'l': '1.02958', 'c': '1.02969'}},
#   {'complete': True,
#    'volume': 46,
#    'time': '2025-01-06T00:42:00.000000000Z',
#    'mid': {'o': '1.02967', 'h': '1.02974', 'l': '1.02966', 'c': '1.02974'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2025-01-06T00:43:00.000000000Z',
#    'mid': {'o': '1.02974', 'h': '1.02975', 'l': '1.02968', 'c': '1.02972'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2025-01-06T00:44:00.000000000Z',
#    'mid': {'o': '1.02973', 'h': '1.02978', 'l': '1.02969', 'c': '1.02969'}},
#   {'complete': True,
#    'volume': 34,
#    'time': '2025-01-06T00:45:00.000000000Z',
#    'mid': {'o': '1.02968', 'h': '1.02973', 'l': '1.02968', 'c': '1.02970'}},
#   {'complete': True,
#    'volume': 31,
#    'time': '2025-01-06T00:46:00.000000000Z',
#    'mid': {'o': '1.02970', 'h': '1.02976', 'l': '1.02968', 'c': '1.02974'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2025-01-06T00:47:00.000000000Z',
#    'mid': {'o': '1.02975', 'h': '1.02975', 'l': '1.02968', 'c': '1.02973'}},
#   {'complete': True,
#    'volume': 42,
#    'time': '2025-01-06T00:48:00.000000000Z',
#    'mid': {'o': '1.02974', 'h': '1.02978', 'l': '1.02973', 'c': '1.02976'}},
#   {'complete': True,
#    'volume': 32,
#    'time': '2025-01-06T00:49:00.000000000Z',
#    'mid': {'o': '1.02977', 'h': '1.02980', 'l': '1.02974', 'c': '1.02976'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2025-01-06T00:50:00.000000000Z',
#    'mid': {'o': '1.02978', 'h': '1.02989', 'l': '1.02976', 'c': '1.02989'}},
#   {'complete': True,
#    'volume': 64,
#    'time': '2025-01-06T00:51:00.000000000Z',
#    'mid': {'o': '1.02988', 'h': '1.02994', 'l': '1.02980', 'c': '1.02994'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2025-01-06T00:52:00.000000000Z',
#    'mid': {'o': '1.02994', 'h': '1.02996', 'l': '1.02990', 'c': '1.02996'}},
#   {'complete': True,
#    'volume': 65,
#    'time': '2025-01-06T00:53:00.000000000Z',
#    'mid': {'o': '1.02998', 'h': '1.03009', 'l': '1.02998', 'c': '1.03002'}},
#   {'complete': True,
#    'volume': 128,
#    'time': '2025-01-06T00:54:00.000000000Z',
#    'mid': {'o': '1.03004', 'h': '1.03014', 'l': '1.03002', 'c': '1.03010'}},
#   {'complete': True,
#    'volume': 96,
#    'time': '2025-01-06T00:55:00.000000000Z',
#    'mid': {'o': '1.03016', 'h': '1.03030', 'l': '1.03008', 'c': '1.03028'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2025-01-06T00:56:00.000000000Z',
#    'mid': {'o': '1.03028', 'h': '1.03042', 'l': '1.03028', 'c': '1.03041'}},
#   {'complete': True,
#    'volume': 73,
#    'time': '2025-01-06T00:57:00.000000000Z',
#    'mid': {'o': '1.03042', 'h': '1.03046', 'l': '1.03036', 'c': '1.03044'}},
#   {'complete': True,
#    'volume': 76,
#    'time': '2025-01-06T00:58:00.000000000Z',
#    'mid': {'o': '1.03045', 'h': '1.03047', 'l': '1.03031', 'c': '1.03032'}},
#   {'complete': True,
#    'volume': 59,
#    'time': '2025-01-06T00:59:00.000000000Z',
#    'mid': {'o': '1.03032', 'h': '1.03038', 'l': '1.03028', 'c': '1.03031'}},
#   {'complete': True,
#    'volume': 157,
#    'time': '2025-01-06T01:00:00.000000000Z',
#    'mid': {'o': '1.03030', 'h': '1.03042', 'l': '1.03022', 'c': '1.03024'}},
#   {'complete': True,
#    'volume': 59,
#    'time': '2025-01-06T01:01:00.000000000Z',
#    'mid': {'o': '1.03022', 'h': '1.03024', 'l': '1.03020', 'c': '1.03022'}},
#   {'complete': True,
#    'volume': 80,
#    'time': '2025-01-06T01:02:00.000000000Z',
#    'mid': {'o': '1.03024', 'h': '1.03028', 'l': '1.03013', 'c': '1.03016'}},
#   {'complete': True,
#    'volume': 49,
#    'time': '2025-01-06T01:03:00.000000000Z',
#    'mid': {'o': '1.03016', 'h': '1.03030', 'l': '1.03014', 'c': '1.03028'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2025-01-06T01:04:00.000000000Z',
#    'mid': {'o': '1.03026', 'h': '1.03030', 'l': '1.03025', 'c': '1.03025'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2025-01-06T01:05:00.000000000Z',
#    'mid': {'o': '1.03026', 'h': '1.03031', 'l': '1.03025', 'c': '1.03030'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2025-01-06T01:06:00.000000000Z',
#    'mid': {'o': '1.03030', 'h': '1.03030', 'l': '1.03018', 'c': '1.03019'}},
#   {'complete': True,
#    'volume': 55,
#    'time': '2025-01-06T01:07:00.000000000Z',
#    'mid': {'o': '1.03018', 'h': '1.03037', 'l': '1.03018', 'c': '1.03034'}},
#   {'complete': True,
#    'volume': 51,
#    'time': '2025-01-06T01:08:00.000000000Z',
#    'mid': {'o': '1.03035', 'h': '1.03044', 'l': '1.03034', 'c': '1.03040'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2025-01-06T01:09:00.000000000Z',
#    'mid': {'o': '1.03040', 'h': '1.03040', 'l': '1.03032', 'c': '1.03034'}},
#   {'complete': True,
#    'volume': 70,
#    'time': '2025-01-06T01:10:00.000000000Z',
#    'mid': {'o': '1.03033', 'h': '1.03038', 'l': '1.03032', 'c': '1.03038'}},
#   {'complete': True,
#    'volume': 52,
#    'time': '2025-01-06T01:11:00.000000000Z',
#    'mid': {'o': '1.03040', 'h': '1.03050', 'l': '1.03038', 'c': '1.03050'}},
#   {'complete': True,
#    'volume': 77,
#    'time': '2025-01-06T01:12:00.000000000Z',
#    'mid': {'o': '1.03049', 'h': '1.03065', 'l': '1.03049', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 65,
#    'time': '2025-01-06T01:13:00.000000000Z',
#    'mid': {'o': '1.03062', 'h': '1.03068', 'l': '1.03060', 'c': '1.03062'}},
#   {'complete': True,
#    'volume': 75,
#    'time': '2025-01-06T01:14:00.000000000Z',
#    'mid': {'o': '1.03062', 'h': '1.03070', 'l': '1.03061', 'c': '1.03065'}},
#   {'complete': True,
#    'volume': 186,
#    'time': '2025-01-06T01:15:00.000000000Z',
#    'mid': {'o': '1.03066', 'h': '1.03102', 'l': '1.03063', 'c': '1.03094'}},
#   {'complete': True,
#    'volume': 83,
#    'time': '2025-01-06T01:16:00.000000000Z',
#    'mid': {'o': '1.03094', 'h': '1.03110', 'l': '1.03092', 'c': '1.03108'}},
#   {'complete': True,
#    'volume': 52,
#    'time': '2025-01-06T01:17:00.000000000Z',
#    'mid': {'o': '1.03107', 'h': '1.03114', 'l': '1.03105', 'c': '1.03108'}},
#   {'complete': True,
#    'volume': 62,
#    'time': '2025-01-06T01:18:00.000000000Z',
#    'mid': {'o': '1.03108', 'h': '1.03114', 'l': '1.03104', 'c': '1.03110'}},
#   {'complete': True,
#    'volume': 62,
#    'time': '2025-01-06T01:19:00.000000000Z',
#    'mid': {'o': '1.03110', 'h': '1.03110', 'l': '1.03105', 'c': '1.03106'}},
#   {'complete': True,
#    'volume': 53,
#    'time': '2025-01-06T01:20:00.000000000Z',
#    'mid': {'o': '1.03104', 'h': '1.03104', 'l': '1.03098', 'c': '1.03100'}},
#   {'complete': True,
#    'volume': 65,
#    'time': '2025-01-06T01:21:00.000000000Z',
#    'mid': {'o': '1.03100', 'h': '1.03104', 'l': '1.03098', 'c': '1.03100'}},
#   {'complete': True,
#    'volume': 58,
#    'time': '2025-01-06T01:22:00.000000000Z',
#    'mid': {'o': '1.03098', 'h': '1.03110', 'l': '1.03097', 'c': '1.03106'}},
#   {'complete': True,
#    'volume': 46,
#    'time': '2025-01-06T01:23:00.000000000Z',
#    'mid': {'o': '1.03109', 'h': '1.03109', 'l': '1.03090', 'c': '1.03090'}},
#   {'complete': True,
#    'volume': 71,
#    'time': '2025-01-06T01:24:00.000000000Z',
#    'mid': {'o': '1.03090', 'h': '1.03090', 'l': '1.03071', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 56,
#    'time': '2025-01-06T01:25:00.000000000Z',
#    'mid': {'o': '1.03071', 'h': '1.03074', 'l': '1.03064', 'c': '1.03072'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2025-01-06T01:26:00.000000000Z',
# ...
#   {'complete': True,
#    'volume': 507,
#    'time': '2025-01-06T11:28:00.000000000Z',
#    'mid': {'o': '1.04077', 'h': '1.04148', 'l': '1.04077', 'c': '1.04110'}},
#   {'complete': True,
#    'volume': 444,
#    'time': '2025-01-06T11:29:00.000000000Z',
#    'mid': {'o': '1.04110', 'h': '1.04163', 'l': '1.04094', 'c': '1.04136'}},
#   {'complete': True,
#    'volume': 598,
#    'time': '2025-01-06T11:30:00.000000000Z',
#    'mid': {'o': '1.04137', 'h': '1.04208', 'l': '1.04130', 'c': '1.04208'}},
#   {'complete': True,
#    'volume': 582,
#    'time': '2025-01-06T11:31:00.000000000Z',
#    'mid': {'o': '1.04208', 'h': '1.04284', 'l': '1.04208', 'c': '1.04284'}},
#   {'complete': True,
#    'volume': 540,
#    'time': '2025-01-06T11:32:00.000000000Z',
#    'mid': {'o': '1.04283', 'h': '1.04283', 'l': '1.04221', 'c': '1.04261'}},
#   {'complete': True,
#    'volume': 576,
#    'time': '2025-01-06T11:33:00.000000000Z',
#    'mid': {'o': '1.04263', 'h': '1.04328', 'l': '1.04256', 'c': '1.04298'}},
#   {'complete': True,
#    'volume': 747,
#    'time': '2025-01-06T11:34:00.000000000Z',
#    'mid': {'o': '1.04297', 'h': '1.04298', 'l': '1.04212', 'c': '1.04230'}},
#   {'complete': True,
#    'volume': 619,
#    'time': '2025-01-06T11:35:00.000000000Z',
#    'mid': {'o': '1.04227', 'h': '1.04234', 'l': '1.04177', 'c': '1.04202'}},
#   {'complete': True,
#    'volume': 342,
#    'time': '2025-01-06T11:36:00.000000000Z',
#    'mid': {'o': '1.04204', 'h': '1.04235', 'l': '1.04204', 'c': '1.04228'}},
#   {'complete': True,
#    'volume': 337,
#    'time': '2025-01-06T11:37:00.000000000Z',
#    'mid': {'o': '1.04228', 'h': '1.04250', 'l': '1.04220', 'c': '1.04226'}},
#   {'complete': True,
#    'volume': 407,
#    'time': '2025-01-06T11:38:00.000000000Z',
#    'mid': {'o': '1.04228', 'h': '1.04238', 'l': '1.04183', 'c': '1.04232'}},
#   {'complete': True,
#    'volume': 373,
#    'time': '2025-01-06T11:39:00.000000000Z',
#    'mid': {'o': '1.04232', 'h': '1.04250', 'l': '1.04220', 'c': '1.04233'}},
#   {'complete': True,
#    'volume': 409,
#    'time': '2025-01-06T11:40:00.000000000Z',
#    'mid': {'o': '1.04234', 'h': '1.04277', 'l': '1.04226', 'c': '1.04256'}},
#   {'complete': True,
#    'volume': 364,
#    'time': '2025-01-06T11:41:00.000000000Z',
#    'mid': {'o': '1.04255', 'h': '1.04255', 'l': '1.04195', 'c': '1.04208'}},
#   {'complete': True,
#    'volume': 385,
#    'time': '2025-01-06T11:42:00.000000000Z',
#    'mid': {'o': '1.04210', 'h': '1.04233', 'l': '1.04201', 'c': '1.04201'}},
#   {'complete': True,
#    'volume': 363,
#    'time': '2025-01-06T11:43:00.000000000Z',
#    'mid': {'o': '1.04202', 'h': '1.04208', 'l': '1.04169', 'c': '1.04184'}},
#   {'complete': True,
#    'volume': 410,
#    'time': '2025-01-06T11:44:00.000000000Z',
#    'mid': {'o': '1.04182', 'h': '1.04211', 'l': '1.04174', 'c': '1.04176'}},
#   {'complete': True,
#    'volume': 340,
#    'time': '2025-01-06T11:45:00.000000000Z',
#    'mid': {'o': '1.04174', 'h': '1.04193', 'l': '1.04125', 'c': '1.04130'}},
#   {'complete': True,
#    'volume': 436,
#    'time': '2025-01-06T11:46:00.000000000Z',
#    'mid': {'o': '1.04129', 'h': '1.04142', 'l': '1.04090', 'c': '1.04106'}},
#   {'complete': True,
#    'volume': 336,
#    'time': '2025-01-06T11:47:00.000000000Z',
#    'mid': {'o': '1.04108', 'h': '1.04134', 'l': '1.04085', 'c': '1.04093'}},
#   {'complete': True,
#    'volume': 363,
#    'time': '2025-01-06T11:48:00.000000000Z',
#    'mid': {'o': '1.04094', 'h': '1.04120', 'l': '1.04094', 'c': '1.04098'}},
#   {'complete': True,
#    'volume': 270,
#    'time': '2025-01-06T11:49:00.000000000Z',
#    'mid': {'o': '1.04098', 'h': '1.04116', 'l': '1.04091', 'c': '1.04110'}},
#   {'complete': True,
#    'volume': 364,
#    'time': '2025-01-06T11:50:00.000000000Z',
#    'mid': {'o': '1.04110', 'h': '1.04153', 'l': '1.04099', 'c': '1.04147'}},
#   {'complete': True,
#    'volume': 255,
#    'time': '2025-01-06T11:51:00.000000000Z',
#    'mid': {'o': '1.04146', 'h': '1.04160', 'l': '1.04131', 'c': '1.04160'}},
#   {'complete': True,
#    'volume': 341,
#    'time': '2025-01-06T11:52:00.000000000Z',
#    'mid': {'o': '1.04160', 'h': '1.04170', 'l': '1.04144', 'c': '1.04160'}},
#   {'complete': True,
#    'volume': 181,
#    'time': '2025-01-06T11:53:00.000000000Z',
#    'mid': {'o': '1.04159', 'h': '1.04175', 'l': '1.04150', 'c': '1.04150'}},
#   {'complete': True,
#    'volume': 303,
#    'time': '2025-01-06T11:54:00.000000000Z',
#    'mid': {'o': '1.04146', 'h': '1.04202', 'l': '1.04145', 'c': '1.04195'}},
#   {'complete': True,
#    'volume': 304,
#    'time': '2025-01-06T11:55:00.000000000Z',
#    'mid': {'o': '1.04194', 'h': '1.04224', 'l': '1.04176', 'c': '1.04202'}},
#   {'complete': True,
#    'volume': 213,
#    'time': '2025-01-06T11:56:00.000000000Z',
#    'mid': {'o': '1.04200', 'h': '1.04222', 'l': '1.04189', 'c': '1.04217'}},
#   {'complete': True,
#    'volume': 248,
#    'time': '2025-01-06T11:57:00.000000000Z',
#    'mid': {'o': '1.04216', 'h': '1.04223', 'l': '1.04199', 'c': '1.04212'}},
#   {'complete': True,
#    'volume': 210,
#    'time': '2025-01-06T11:58:00.000000000Z',
#    'mid': {'o': '1.04212', 'h': '1.04216', 'l': '1.04200', 'c': '1.04202'}},
#   {'complete': True,
#    'volume': 140,
#    'time': '2025-01-06T11:59:00.000000000Z',
#    'mid': {'o': '1.04201', 'h': '1.04220', 'l': '1.04200', 'c': '1.04220'}},
#   {'complete': True,
#    'volume': 261,
#    'time': '2025-01-06T12:00:00.000000000Z',
#    'mid': {'o': '1.04220', 'h': '1.04249', 'l': '1.04216', 'c': '1.04249'}},
#   {'complete': True,
#    'volume': 226,
#    'time': '2025-01-06T12:01:00.000000000Z',
#    'mid': {'o': '1.04248', 'h': '1.04272', 'l': '1.04217', 'c': '1.04219'}},
#   {'complete': True,
#    'volume': 274,
#    'time': '2025-01-06T12:02:00.000000000Z',
#    'mid': {'o': '1.04217', 'h': '1.04278', 'l': '1.04217', 'c': '1.04266'}},
#   {'complete': True,
#    'volume': 212,
#    'time': '2025-01-06T12:03:00.000000000Z',
#    'mid': {'o': '1.04266', 'h': '1.04306', 'l': '1.04258', 'c': '1.04293'}},
#   {'complete': True,
#    'volume': 256,
#    'time': '2025-01-06T12:04:00.000000000Z',
#    'mid': {'o': '1.04294', 'h': '1.04298', 'l': '1.04235', 'c': '1.04236'}},
#   {'complete': True,
#    'volume': 189,
#    'time': '2025-01-06T12:05:00.000000000Z',
#    'mid': {'o': '1.04235', 'h': '1.04260', 'l': '1.04235', 'c': '1.04246'}},
#   {'complete': True,
#    'volume': 233,
#    'time': '2025-01-06T12:06:00.000000000Z',
#    'mid': {'o': '1.04248', 'h': '1.04259', 'l': '1.04218', 'c': '1.04220'}},
#   {'complete': True,
#    'volume': 283,
#    'time': '2025-01-06T12:07:00.000000000Z',
#    'mid': {'o': '1.04220', 'h': '1.04220', 'l': '1.04164', 'c': '1.04170'}},
#   {'complete': True,
#    'volume': 197,
#    'time': '2025-01-06T12:08:00.000000000Z',
#    'mid': {'o': '1.04172', 'h': '1.04192', 'l': '1.04170', 'c': '1.04174'}},
#   {'complete': True,
#    'volume': 206,
#    'time': '2025-01-06T12:09:00.000000000Z',
#    'mid': {'o': '1.04175', 'h': '1.04198', 'l': '1.04166', 'c': '1.04172'}},
#   {'complete': True,
#    'volume': 285,
#    'time': '2025-01-06T12:10:00.000000000Z',
#    'mid': {'o': '1.04173', 'h': '1.04184', 'l': '1.04136', 'c': '1.04144'}},
#   {'complete': True,
#    'volume': 249,
#    'time': '2025-01-06T12:11:00.000000000Z',
#    'mid': {'o': '1.04144', 'h': '1.04144', 'l': '1.04107', 'c': '1.04108'}},
#   {'complete': True,
#    'volume': 250,
#    'time': '2025-01-06T12:12:00.000000000Z',
#    'mid': {'o': '1.04107', 'h': '1.04136', 'l': '1.04104', 'c': '1.04130'}},
#   {'complete': True,
#    'volume': 253,
#    'time': '2025-01-06T12:13:00.000000000Z',
#    'mid': {'o': '1.04130', 'h': '1.04149', 'l': '1.04123', 'c': '1.04130'}},
#   {'complete': True,
#    'volume': 228,
#    'time': '2025-01-06T12:14:00.000000000Z',
#    'mid': {'o': '1.04130', 'h': '1.04144', 'l': '1.04104', 'c': '1.04106'}},
#   {'complete': True,
#    'volume': 189,
#    'time': '2025-01-06T12:15:00.000000000Z',
#    'mid': {'o': '1.04106', 'h': '1.04142', 'l': '1.04100', 'c': '1.04130'}},
#   {'complete': True,
#    'volume': 228,
#    'time': '2025-01-06T12:16:00.000000000Z',
#    'mid': {'o': '1.04129', 'h': '1.04150', 'l': '1.04127', 'c': '1.04138'}},
#   {'complete': True,
#    'volume': 199,
#    'time': '2025-01-06T12:17:00.000000000Z',
#    'mid': {'o': '1.04139', 'h': '1.04181', 'l': '1.04139', 'c': '1.04162'}},
#   {'complete': True,
#    'volume': 158,
#    'time': '2025-01-06T12:18:00.000000000Z',
#    'mid': {'o': '1.04160', 'h': '1.04162', 'l': '1.04120', 'c': '1.04120'}},
#   {'complete': True,
#    'volume': 256,
#    'time': '2025-01-06T12:19:00.000000000Z',
#    'mid': {'o': '1.04120', 'h': '1.04136', 'l': '1.04102', 'c': '1.04102'}},
#   {'complete': True,
#    'volume': 196,
#    'time': '2025-01-06T12:20:00.000000000Z',
#    'mid': {'o': '1.04098', 'h': '1.04134', 'l': '1.04094', 'c': '1.04104'}},
#   {'complete': True,
#    'volume': 182,
#    'time': '2025-01-06T12:21:00.000000000Z',
#    'mid': {'o': '1.04104', 'h': '1.04110', 'l': '1.04060', 'c': '1.04063'}},
#   {'complete': True,
#    'volume': 175,
#    'time': '2025-01-06T12:22:00.000000000Z',
#    'mid': {'o': '1.04062', 'h': '1.04082', 'l': '1.04062', 'c': '1.04073'}},
#   {'complete': True,
#    'volume': 217,
#    'time': '2025-01-06T12:23:00.000000000Z',
#    'mid': {'o': '1.04076', 'h': '1.04082', 'l': '1.04024', 'c': '1.04040'}},
#   {'complete': True,
#    'volume': 307,
#    'time': '2025-01-06T12:24:00.000000000Z',
#    'mid': {'o': '1.04040', 'h': '1.04042', 'l': '1.04016', 'c': '1.04030'}},
#   {'complete': True,
#    'volume': 310,
#    'time': '2025-01-06T12:25:00.000000000Z',
#    'mid': {'o': '1.04030', 'h': '1.04044', 'l': '1.03997', 'c': '1.04042'}},
#   {'complete': True,
#    'volume': 283,
#    'time': '2025-01-06T12:26:00.000000000Z',
#    'mid': {'o': '1.04044', 'h': '1.04062', 'l': '1.04036', 'c': '1.04044'}},
#   {'complete': True,
#    'volume': 196,
#    'time': '2025-01-06T12:27:00.000000000Z',
#    'mid': {'o': '1.04045', 'h': '1.04060', 'l': '1.04034', 'c': '1.04036'}},
#   {'complete': True,
#    'volume': 207,
#    'time': '2025-01-06T12:28:00.000000000Z',
#    'mid': {'o': '1.04034', 'h': '1.04036', 'l': '1.04004', 'c': '1.04005'}},
#   {'complete': True,
#    'volume': 243,
#    'time': '2025-01-06T12:29:00.000000000Z',
#    'mid': {'o': '1.04008', 'h': '1.04008', 'l': '1.03985', 'c': '1.03992'}},
#   {'complete': True,
#    'volume': 389,
#    'time': '2025-01-06T12:30:00.000000000Z',
#    'mid': {'o': '1.03992', 'h': '1.03992', 'l': '1.03922', 'c': '1.03930'}},
#   {'complete': True,
#    'volume': 231,
#    'time': '2025-01-06T12:31:00.000000000Z',
#    'mid': {'o': '1.03932', 'h': '1.03944', 'l': '1.03926', 'c': '1.03930'}},
#   {'complete': True,
#    'volume': 202,
#    'time': '2025-01-06T12:32:00.000000000Z',
#    'mid': {'o': '1.03930', 'h': '1.03951', 'l': '1.03930', 'c': '1.03951'}},
#   {'complete': True,
#    'volume': 246,
#    'time': '2025-01-06T12:33:00.000000000Z',
#    'mid': {'o': '1.03949', 'h': '1.04018', 'l': '1.03949', 'c': '1.04010'}},
#   {'complete': True,
#    'volume': 280,
#    'time': '2025-01-06T12:34:00.000000000Z',
#    'mid': {'o': '1.04010', 'h': '1.04024', 'l': '1.03992', 'c': '1.03992'}},
#   {'complete': True,
#    'volume': 209,
#    'time': '2025-01-06T12:35:00.000000000Z',
#    'mid': {'o': '1.03993', 'h': '1.04059', 'l': '1.03992', 'c': '1.04052'}},
#   {'complete': True,
#    'volume': 202,
#    'time': '2025-01-06T12:36:00.000000000Z',
#    'mid': {'o': '1.04052', 'h': '1.04072', 'l': '1.04046', 'c': '1.04058'}},
#   {'complete': True,
#    'volume': 184,
#    'time': '2025-01-06T12:37:00.000000000Z',
#    'mid': {'o': '1.04058', 'h': '1.04062', 'l': '1.04042', 'c': '1.04045'}},
#   {'complete': True,
#    'volume': 232,
#    'time': '2025-01-06T12:38:00.000000000Z',
#    'mid': {'o': '1.04046', 'h': '1.04067', 'l': '1.04040', 'c': '1.04054'}},
#   {'complete': True,
#    'volume': 206,
#    'time': '2025-01-06T12:39:00.000000000Z',
#    'mid': {'o': '1.04052', 'h': '1.04063', 'l': '1.04038', 'c': '1.04044'}},
#   {'complete': True,
#    'volume': 169,
#    'time': '2025-01-06T12:40:00.000000000Z',
#    'mid': {'o': '1.04041', 'h': '1.04046', 'l': '1.04033', 'c': '1.04036'}},
#   {'complete': True,
#    'volume': 163,
#    'time': '2025-01-06T12:41:00.000000000Z',
#    'mid': {'o': '1.04036', 'h': '1.04045', 'l': '1.04024', 'c': '1.04034'}},
#   {'complete': True,
#    'volume': 136,
#    'time': '2025-01-06T12:42:00.000000000Z',
#    'mid': {'o': '1.04034', 'h': '1.04036', 'l': '1.04012', 'c': '1.04026'}},
#   {'complete': True,
#    'volume': 229,
#    'time': '2025-01-06T12:43:00.000000000Z',
#    'mid': {'o': '1.04023', 'h': '1.04050', 'l': '1.04022', 'c': '1.04049'}},
#   {'complete': True,
#    'volume': 130,
#    'time': '2025-01-06T12:44:00.000000000Z',
#    'mid': {'o': '1.04048', 'h': '1.04048', 'l': '1.04032', 'c': '1.04047'}},
#   {'complete': True,
#    'volume': 217,
#    'time': '2025-01-06T12:45:00.000000000Z',
#    'mid': {'o': '1.04048', 'h': '1.04064', 'l': '1.04035', 'c': '1.04056'}},
#   {'complete': True,
#    'volume': 273,
#    'time': '2025-01-06T12:46:00.000000000Z',
#    'mid': {'o': '1.04058', 'h': '1.04066', 'l': '1.04024', 'c': '1.04032'}},
#   {'complete': True,
#    'volume': 319,
#    'time': '2025-01-06T12:47:00.000000000Z',
#    'mid': {'o': '1.04032', 'h': '1.04087', 'l': '1.04032', 'c': '1.04070'}},
#   {'complete': True,
#    'volume': 170,
#    'time': '2025-01-06T12:48:00.000000000Z',
#    'mid': {'o': '1.04069', 'h': '1.04082', 'l': '1.04062', 'c': '1.04068'}},
#   {'complete': True,
#    'volume': 267,
#    'time': '2025-01-06T12:49:00.000000000Z',
#    'mid': {'o': '1.04068', 'h': '1.04076', 'l': '1.04050', 'c': '1.04070'}},
#   {'complete': True,
#    'volume': 260,
#    'time': '2025-01-06T12:50:00.000000000Z',
#    'mid': {'o': '1.04070', 'h': '1.04076', 'l': '1.04026', 'c': '1.04026'}},
#   {'complete': True,
#    'volume': 221,
#    'time': '2025-01-06T12:51:00.000000000Z',
#    'mid': {'o': '1.04026', 'h': '1.04038', 'l': '1.04002', 'c': '1.04008'}},
#   {'complete': True,
#    'volume': 199,
#    'time': '2025-01-06T12:52:00.000000000Z',
#    'mid': {'o': '1.04009', 'h': '1.04014', 'l': '1.03981', 'c': '1.03986'}},
#   {'complete': True,
#    'volume': 196,
#    'time': '2025-01-06T12:53:00.000000000Z',
#    'mid': {'o': '1.03986', 'h': '1.04002', 'l': '1.03961', 'c': '1.03970'}},
#   {'complete': True,
#    'volume': 213,
#    'time': '2025-01-06T12:54:00.000000000Z',
#    'mid': {'o': '1.03971', 'h': '1.04010', 'l': '1.03969', 'c': '1.04004'}},
#   {'complete': True,
#    'volume': 248,
#    'time': '2025-01-06T12:55:00.000000000Z',
#    'mid': {'o': '1.04003', 'h': '1.04030', 'l': '1.04000', 'c': '1.04028'}},
#   {'complete': True,
#    'volume': 97,
#    'time': '2025-01-06T12:56:00.000000000Z',
#    'mid': {'o': '1.04027', 'h': '1.04046', 'l': '1.04022', 'c': '1.04046'}},
#   {'complete': True,
#    'volume': 183,
#    'time': '2025-01-06T12:57:00.000000000Z',
#    'mid': {'o': '1.04045', 'h': '1.04068', 'l': '1.04033', 'c': '1.04068'}},
#   {'complete': True,
#    'volume': 405,
#    'time': '2025-01-06T12:58:00.000000000Z',
#    'mid': {'o': '1.04068', 'h': '1.04134', 'l': '1.04068', 'c': '1.04130'}},
#   {'complete': True,
#    'volume': 363,
#    'time': '2025-01-06T12:59:00.000000000Z',
#    'mid': {'o': '1.04129', 'h': '1.04135', 'l': '1.04090', 'c': '1.04112'}},
#   {'complete': True,
#    'volume': 288,
#    'time': '2025-01-06T13:00:00.000000000Z',
#    'mid': {'o': '1.04114', 'h': '1.04163', 'l': '1.04107', 'c': '1.04137'}},
#   {'complete': True,
#    'volume': 229,
#    'time': '2025-01-06T13:01:00.000000000Z',
#    'mid': {'o': '1.04138', 'h': '1.04185', 'l': '1.04134', 'c': '1.04185'}},
#   {'complete': True,
#    'volume': 305,
#    'time': '2025-01-06T13:02:00.000000000Z',
#    'mid': {'o': '1.04188', 'h': '1.04204', 'l': '1.04182', 'c': '1.04196'}},
#   {'complete': True,
#    'volume': 282,
#    'time': '2025-01-06T13:03:00.000000000Z',
#    'mid': {'o': '1.04195', 'h': '1.04202', 'l': '1.04176', 'c': '1.04180'}},
#   {'complete': True,
#    'volume': 349,
#    'time': '2025-01-06T13:04:00.000000000Z',
#    'mid': {'o': '1.04182', 'h': '1.04185', 'l': '1.04160', 'c': '1.04166'}},
#   {'complete': True,
#    'volume': 276,
#    'time': '2025-01-06T13:05:00.000000000Z',
#    'mid': {'o': '1.04166', 'h': '1.04196', 'l': '1.04165', 'c': '1.04172'}},
#   {'complete': True,
#    'volume': 346,
#    'time': '2025-01-06T13:06:00.000000000Z',
#    'mid': {'o': '1.04172', 'h': '1.04199', 'l': '1.04172', 'c': '1.04198'}},
#   ...]}

# %% [markdown]
# #### Converting data into dataframe

# %%
def convert_to_df(data):
    hist_data = []
    for candle in data['candles']:
        if candle['complete']:
            hist = dict(
                time=candle['time'],
                volume=candle['volume'],
                open=float(candle['mid']['o']),
                low=float(candle['mid']['l']),
                high=float(candle['mid']['h']),
                close=float(candle['mid']['c']),
            )
            hist_data.append(hist)

    df = pd.DataFrame(hist_data)
    return df

# %%
# Test convert to df function
data = convert_to_df(raw_data)
data
# Out:
#                                 time  volume     open      low     high  \
# 0     2025-01-03T20:20:00.000000000Z      87  1.03060  1.03048  1.03064
# 1     2025-01-03T20:21:00.000000000Z      59  1.03051  1.03048  1.03054
# 2     2025-01-03T20:22:00.000000000Z      50  1.03055  1.03052  1.03062
# 3     2025-01-03T20:23:00.000000000Z      29  1.03061  1.03056  1.03062
# 4     2025-01-03T20:24:00.000000000Z      88  1.03056  1.03046  1.03058
# ...                              ...     ...      ...      ...      ...
# 4994  2025-01-09T08:06:00.000000000Z     246  1.02884  1.02878  1.02920
# 4995  2025-01-09T08:07:00.000000000Z     201  1.02902  1.02896  1.02924
# 4996  2025-01-09T08:08:00.000000000Z     163  1.02912  1.02897  1.02918
# 4997  2025-01-09T08:09:00.000000000Z     218  1.02897  1.02897  1.02930
# 4998  2025-01-09T08:10:00.000000000Z     186  1.02923  1.02918  1.02936
#
#         close
# 0     1.03053
# 1     1.03053
# 2     1.03062
# 3     1.03057
# 4     1.03047
# ...       ...
# 4994  1.02904
# 4995  1.02912
# 4996  1.02898
# 4997  1.02924
# 4998  1.02934
#
# [4999 rows x 6 columns]

# %%
def is_trade(row):
    try:
        if row['cross'] == 1 and row['close'] > row['EMA_200']: # close > ema200 is uptrend
            isTrade = True
            stoploss = row['last_low']
            lossdept = abs(row['close'] - stoploss)
            takeprofit = max(row['last_high'], row['close'] + 2 * lossdept)  # Ensure TP is 2x SL
            
            return isTrade, takeprofit, stoploss

        if row['cross'] == -1 and row['close'] < row['EMA_200']: # close < ema200 is downtrend
            isTrade = True
            stoploss = row['last_high']
            lossdept = abs(row['close'] - stoploss)
            takeprofit = min(row['close'] - 2 * lossdept, row['last_low'])  # Ensure TP is 2x SL
            
            return isTrade, takeprofit, stoploss
    except Exception as e:
        print(f"Error: {e}")
    
    return False, None, None

# %%
def transform_data(data):
    df = data.copy()

    # Calculate EMAs
    df['EMA_200'] = df['close'].ewm(span=200, adjust=False).mean()
    df['EMA_50'] = df['close'].ewm(span=50, adjust=False).mean()
    df['EMA_20'] = df['close'].ewm(span=20, adjust=False).mean()

    # Caluculate the difference between the EMAs
    df['diff'] =  df['EMA_20'] - df['EMA_50']

    # Determine the previous difference
    df['diff_prev'] = df['diff'].shift(1)

    # If cross downward, set to -1, if cross upward, set to 1
    df['cross'] = ((df['diff'] > 0) & (df['diff_prev'] < 0)).astype(int) - \
                    ((df['diff'] < 0) & (df['diff_prev'] > 0)).astype(int)

    # Calculate the low and high for the last 50 candles
    df['last_low'] = df['low'].rolling(window=50, min_periods=1).min()
    df['last_high'] = df['high'].rolling(window=50, min_periods=1).max()

    # Determine the trade signals
    df[['isTrade', 'takeprofit', 'stoploss']] = df.apply(is_trade, axis=1, result_type="expand")

    return df

# %%
## Testing the transform_data function
df =  transform_data(data)
df
# Out:
#                                 time  volume     open      low     high  \
# 0     2025-01-03T20:20:00.000000000Z      87  1.03060  1.03048  1.03064
# 1     2025-01-03T20:21:00.000000000Z      59  1.03051  1.03048  1.03054
# 2     2025-01-03T20:22:00.000000000Z      50  1.03055  1.03052  1.03062
# 3     2025-01-03T20:23:00.000000000Z      29  1.03061  1.03056  1.03062
# 4     2025-01-03T20:24:00.000000000Z      88  1.03056  1.03046  1.03058
# ...                              ...     ...      ...      ...      ...
# 4994  2025-01-09T08:06:00.000000000Z     246  1.02884  1.02878  1.02920
# 4995  2025-01-09T08:07:00.000000000Z     201  1.02902  1.02896  1.02924
# 4996  2025-01-09T08:08:00.000000000Z     163  1.02912  1.02897  1.02918
# 4997  2025-01-09T08:09:00.000000000Z     218  1.02897  1.02897  1.02930
# 4998  2025-01-09T08:10:00.000000000Z     186  1.02923  1.02918  1.02936
#
#         close   EMA_200    EMA_50    EMA_20      diff  diff_prev  cross  \
# 0     1.03053  1.030530  1.030530  1.030530  0.000000        NaN      0
# 1     1.03053  1.030530  1.030530  1.030530  0.000000   0.000000      0
# 2     1.03062  1.030531  1.030534  1.030539  0.000005   0.000000      0
# 3     1.03057  1.030531  1.030535  1.030542  0.000007   0.000005      0
# 4     1.03047  1.030531  1.030532  1.030535  0.000002   0.000007      0
# ...       ...       ...       ...       ...       ...        ...    ...
# 4994  1.02904  1.030296  1.029581  1.029197 -0.000384  -0.000389      0
# 4995  1.02912  1.030284  1.029563  1.029190 -0.000373  -0.000384      0
# 4996  1.02898  1.030271  1.029540  1.029170 -0.000370  -0.000373      0
# 4997  1.02924  1.030261  1.029528  1.029176 -0.000352  -0.000370      0
# 4998  1.02934  1.030252  1.029521  1.029192 -0.000329  -0.000352      0
#
#       last_low  last_high  isTrade  takeprofit  stoploss
# 0      1.03048    1.03064    False         NaN       NaN
# 1      1.03048    1.03064    False         NaN       NaN
# 2      1.03048    1.03064    False         NaN       NaN
# 3      1.03048    1.03064    False         NaN       NaN
# 4      1.03046    1.03064    False         NaN       NaN
# ...        ...        ...      ...         ...       ...
# 4994   1.02836    1.03076    False         NaN       NaN
# 4995   1.02836    1.03076    False         NaN       NaN
# 4996   1.02836    1.03076    False         NaN       NaN
# 4997   1.02836    1.03076    False         NaN       NaN
# 4998   1.02836    1.03076    False         NaN       NaN
#
# [4999 rows x 17 columns]

# %%
df[df['cross'] != 0]
# Out:
#                                 time  volume     open      low     high  \
# 6     2025-01-03T20:26:00.000000000Z      47  1.03051  1.03041  1.03052
# 37    2025-01-03T20:57:00.000000000Z     102  1.03061  1.03053  1.03067
# 103   2025-01-05T22:09:00.000000000Z       3  1.03048  1.03048  1.03049
# 129   2025-01-05T22:36:00.000000000Z      10  1.03072  1.03072  1.03074
# 145   2025-01-05T22:52:00.000000000Z      41  1.03048  1.03016  1.03052
# ...                              ...     ...      ...      ...      ...
# 4862  2025-01-09T05:54:00.000000000Z      48  1.03098  1.03096  1.03104
# 4914  2025-01-09T06:46:00.000000000Z      63  1.03061  1.03060  1.03069
# 4924  2025-01-09T06:56:00.000000000Z     183  1.03026  1.02990  1.03026
# 4943  2025-01-09T07:15:00.000000000Z     116  1.03055  1.03053  1.03084
# 4958  2025-01-09T07:30:00.000000000Z     252  1.03036  1.03002  1.03038
#
#         close   EMA_200    EMA_50    EMA_20          diff     diff_prev  \
# 6     1.03044  1.030530  1.030528  1.030524 -3.866169e-06  1.418844e-06
# 37    1.03067  1.030477  1.030408  1.030422  1.472805e-05 -6.352311e-07
# 103   1.03049  1.030599  1.030691  1.030681 -1.012043e-05  1.792056e-06
# 129   1.03074  1.030590  1.030620  1.030622  2.501591e-06 -4.990332e-06
# 145   1.03020  1.030598  1.030625  1.030608 -1.604046e-05  9.631036e-06
# ...       ...       ...       ...       ...           ...           ...
# 4862  1.03098  1.031169  1.031024  1.031023 -9.146952e-07  1.800294e-06
# 4914  1.03060  1.030830  1.030446  1.030455  8.145685e-06 -8.919318e-07
# 4924  1.02991  1.030799  1.030459  1.030449 -9.842356e-06  2.448743e-05
# 4943  1.03078  1.030714  1.030394  1.030401  6.494557e-06 -1.769512e-05
# 4958  1.03008  1.030675  1.030406  1.030389 -1.638977e-05  2.862477e-06
#
#       cross  last_low  last_high  isTrade  takeprofit  stoploss
# 6        -1   1.03041    1.03064     True     1.03004   1.03064
# 37        1   1.03010    1.03067     True     1.03181   1.03010
# 103      -1   1.03048    1.03094     True     1.02959   1.03094
# 129       1   1.03037    1.03094     True     1.03148   1.03037
# 145      -1   1.03016    1.03092     True     1.02876   1.03092
# ...     ...       ...        ...      ...         ...       ...
# 4862     -1   1.03083    1.03127     True     1.03040   1.03127
# 4914      1   1.02971    1.03070    False         NaN       NaN
# 4924     -1   1.02971    1.03084     True     1.02805   1.03084
# 4943      1   1.02972    1.03084     True     1.03290   1.02972
# 4958     -1   1.02972    1.03084     True     1.02856   1.03084
#
# [99 rows x 17 columns]

# %% [markdown]
# #### Function to calculate position price base on account balance

# %%
def calculate_position_size(account_balance, risk_percentage, entry_price, stop_loss_price):
    # Calculate risk amount
    risk_amount = account_balance * risk_percentage /100

     # Calculate position size
    risk_per_unit = abs(entry_price - stop_loss_price)
    if risk_per_unit == 0:
        raise ValueError("Entry price and stop loss price cannot be the same.")

    position_size = risk_amount / risk_per_unit
    return round(position_size)

# %%
def test(period, instrument):
    
    raw_data = fetch_data(instrument,period, 5000)
    data = convert_to_df(raw_data)
    df =  transform_data(data)
    in_position, entry = False, False
    account_balance = 1000
    risk = 1 # percentage risk
    stoploss = 0
    takeprofit = 0
    position_size = 0
    transaction = []

    for _, row in df.iterrows():
        # print(row)
        if  in_position == False:
            if row['isTrade']: 
                in_position = True
                entryprice = row['close']
                stoploss = row['stoploss']
                takeprofit = row['takeprofit']
                try:
                    position_size = calculate_position_size(account_balance,risk,entryprice,stoploss)
                except:
                    continue
            
                transaction.append({
                    "type" : "Short" if stoploss > entryprice else "Long",
                    "entry" : entryprice,
                    "SL" : stoploss,
                    "TP" : takeprofit,
                    "size" :position_size,
                    "status" : "incomplete",
                    "winloss" : 0
                })

        else:
            try:
                if transaction[-1]['type'] == "Long":
                    if transaction[-1]['SL'] > row['low'] :
                        transaction[-1]['status'] = "complete"
                        transaction[-1]['winloss'] = transaction[-1]['size'] * (transaction[-1]['SL'] - transaction[-1]['entry'] )
                        account_balance += transaction[-1]['winloss']
                        in_position = False
                    
                    if transaction[-1]['TP'] < row['high']:
                        transaction[-1]['status'] = "complete"
                        transaction[-1]['winloss'] = transaction[-1]['size'] * abs(transaction[-1]['TP'] - transaction[-1]['entry'] )
                        account_balance += transaction[-1]['winloss']
                        in_position = False
                    
                
                if transaction[-1]['type'] == "Short":
                    if transaction[-1]['SL'] < row['high'] :
                        transaction[-1]['status'] = "complete"
                        transaction[-1]['winloss'] = transaction[-1]['size'] * (transaction[-1]['entry'] - transaction[-1]['SL'] )
                        account_balance += transaction[-1]['winloss']
                        in_position = False

                    if transaction[-1]['TP'] > row['low']:
                        transaction[-1]['status'] = "complete"
                        transaction[-1]['winloss'] = transaction[-1]['size'] * abs(transaction[-1]['TP'] - transaction[-1]['entry'] )
                        account_balance += transaction[-1]['winloss']
                        in_position = False
            except:
                transaction = None

   
    df_transaction = pd.DataFrame(transaction)
    df_transaction.to_csv("transaction.csv")
    
    try :
        winrate = len(df_transaction[df_transaction['winloss']>0] ) / len(df_transaction) * 100
    except:
        winrate = 0
    print(f"Pair: {instrument} \tTime :{period} \tBalance: {account_balance:2f} \tWinrate : {winrate:2f}")
    numTrade = len(df_transaction)

    return instrument, period, account_balance, winrate, numTrade

# %%
result = []
pairs = ["EUR_USD","USD_JPY","GBP_USD","USD_CAD","AUD_USD","USD_CHF","USD_HKD","EUR_GBP","XAU_USD"]
periods = ["S5", "S10","S15","S30","M1"]


for pair in pairs:
    for period in periods:
        instrument, period, account_balance, winrate, numTrade = test(period,pair)
        result.append({
            "instrument" : instrument,
            "period" : period,
            "balance" : account_balance,
            "numtrade" : numTrade,
            "winrate" : winrate

        })

df = pd.DataFrame(result)
print(df.sort_values("balance",ascending=False))
# Out:
# Pair: EUR_USD 	Time :S5 	Balance: 1017.873750 	Winrate : 36.363636
# Pair: EUR_USD 	Time :S10 	Balance: 1007.695350 	Winrate : 34.782609
# Pair: EUR_USD 	Time :S15 	Balance: 949.008900 	Winrate : 26.923077
# Pair: EUR_USD 	Time :S30 	Balance: 1008.297660 	Winrate : 33.333333
# Pair: EUR_USD 	Time :M1 	Balance: 998.213170 	Winrate : 31.578947
# Pair: USD_JPY 	Time :S5 	Balance: 1113.511000 	Winrate : 52.631579
# Pair: USD_JPY 	Time :S10 	Balance: 1113.261000 	Winrate : 50.000000
# Pair: USD_JPY 	Time :S15 	Balance: 998.168000 	Winrate : 33.333333
# Pair: USD_JPY 	Time :S30 	Balance: 1017.798000 	Winrate : 36.000000
# Pair: USD_JPY 	Time :M1 	Balance: 1039.261000 	Winrate : 40.000000
# Pair: GBP_USD 	Time :S5 	Balance: 1146.975340 	Winrate : 52.173913
# Pair: GBP_USD 	Time :S10 	Balance: 1028.155580 	Winrate : 38.095238
# Pair: GBP_USD 	Time :S15 	Balance: 1038.231540 	Winrate : 39.130435
# Pair: GBP_USD 	Time :S30 	Balance: 1070.015130 	Winrate : 45.000000
# Pair: GBP_USD 	Time :M1 	Balance: 978.928790 	Winrate : 28.571429
# Pair: USD_CAD 	Time :S5 	Balance: 988.231220 	Winrate : 31.578947
# Pair: USD_CAD 	Time :S10 	Balance: 921.645390 	Winrate : 20.000000
# Pair: USD_CAD 	Time :S15 	Balance: 978.641690 	Winrate : 29.411765
# Pair: USD_CAD 	Time :S30 	Balance: 1058.680940 	Winrate : 40.740741
# Pair: USD_CAD 	Time :M1 	Balance: 1114.903580 	Winrate : 75.000000
# Pair: AUD_USD 	Time :S5 	Balance: 1029.688720 	Winrate : 50.000000
# Pair: AUD_USD 	Time :S10 	Balance: 959.737630 	Winrate : 23.076923
# Pair: AUD_USD 	Time :S15 	Balance: 930.677150 	Winrate : 22.727273
# Pair: AUD_USD 	Time :S30 	Balance: 1049.971820 	Winrate : 50.000000
# Pair: AUD_USD 	Time :M1 	Balance: 997.027340 	Winrate : 33.333333
# Pair: USD_CHF 	Time :S5 	Balance: 1049.031420 	Winrate : 42.105263
# Pair: USD_CHF 	Time :S10 	Balance: 959.737520 	Winrate : 23.076923
# Pair: USD_CHF 	Time :S15 	Balance: 950.140690 	Winrate : 21.428571
# Pair: USD_CHF 	Time :S30 	Balance: 958.879500 	Winrate : 27.272727
# Pair: USD_CHF 	Time :M1 	Balance: 978.346720 	Winrate : 30.000000
# Pair: USD_HKD 	Time :S5 	Balance: 997.915570 	Winrate : 31.818182
# Pair: USD_HKD 	Time :S10 	Balance: 997.915680 	Winrate : 31.818182
# Pair: USD_HKD 	Time :S15 	Balance: 930.954210 	Winrate : 20.000000
# Pair: USD_HKD 	Time :S30 	Balance: 969.142750 	Winrate : 26.666667
# Pair: USD_HKD 	Time :M1 	Balance: 978.348790 	Winrate : 30.000000
# Pair: EUR_GBP 	Time :S5 	Balance: 1091.738290 	Winrate : 50.000000
# Pair: EUR_GBP 	Time :S10 	Balance: 1049.031120 	Winrate : 40.000000
# Pair: EUR_GBP 	Time :S15 	Balance: 1159.943100 	Winrate : 88.888889
# Pair: EUR_GBP 	Time :S30 	Balance: 1029.075860 	Winrate : 41.666667
# Pair: EUR_GBP 	Time :M1 	Balance: 913.245830 	Winrate : 8.333333
# Pair: XAU_USD 	Time :S5 	Balance: 1009.805000 	Winrate : 33.333333
# Pair: XAU_USD 	Time :S10 	Balance: 945.275000 	Winrate : 25.000000
# Pair: XAU_USD 	Time :S15 	Balance: 977.720000 	Winrate : 30.000000
# Pair: XAU_USD 	Time :S30 	Balance: 836.965000 	Winrate : 11.538462
# Pair: XAU_USD 	Time :M1 	Balance: 1020.460000 	Winrate : 38.888889
#    instrument period     balance  numtrade    winrate
# 37    EUR_GBP    S15  1159.94310         9  88.888889
# 10    GBP_USD     S5  1146.97534        23  52.173913
# 19    USD_CAD     M1  1114.90358         8  75.000000
# 5     USD_JPY     S5  1113.51100        19  52.631579
# 6     USD_JPY    S10  1113.26100        22  50.000000
# 35    EUR_GBP     S5  1091.73829        18  50.000000
# 13    GBP_USD    S30  1070.01513        20  45.000000
# 18    USD_CAD    S30  1058.68094        27  40.740741
# 23    AUD_USD    S30  1049.97182        10  50.000000
# 25    USD_CHF     S5  1049.03142        19  42.105263
# 36    EUR_GBP    S10  1049.03112        20  40.000000
# 9     USD_JPY     M1  1039.26100        15  40.000000
# 12    GBP_USD    S15  1038.23154        23  39.130435
# 20    AUD_USD     S5  1029.68872         6  50.000000
# 38    EUR_GBP    S30  1029.07586        12  41.666667
# 11    GBP_USD    S10  1028.15558        21  38.095238
# 44    XAU_USD     M1  1020.46000        18  38.888889
# 0     EUR_USD     S5  1017.87375        22  36.363636
# 8     USD_JPY    S30  1017.79800        25  36.000000
# 40    XAU_USD     S5  1009.80500        24  33.333333
# 3     EUR_USD    S30  1008.29766        18  33.333333
# 1     EUR_USD    S10  1007.69535        23  34.782609
# 4     EUR_USD     M1   998.21317        19  31.578947
# 7     USD_JPY    S15   998.16800        18  33.333333
# 31    USD_HKD    S10   997.91568        22  31.818182
# 30    USD_HKD     S5   997.91557        22  31.818182
# 24    AUD_USD     M1   997.02734        30  33.333333
# 15    USD_CAD     S5   988.23122        19  31.578947
# 14    GBP_USD     M1   978.92879        14  28.571429
# 17    USD_CAD    S15   978.64169        17  29.411765
# 34    USD_HKD     M1   978.34879        20  30.000000
# 29    USD_CHF     M1   978.34672        20  30.000000
# 42    XAU_USD    S15   977.72000        20  30.000000
# 33    USD_HKD    S30   969.14275        15  26.666667
# 21    AUD_USD    S10   959.73763        13  23.076923
# 26    USD_CHF    S10   959.73752        13  23.076923
# 28    USD_CHF    S30   958.87950        22  27.272727
# 27    USD_CHF    S15   950.14069        14  21.428571
# 2     EUR_USD    S15   949.00890        26  26.923077
# 41    XAU_USD    S10   945.27500        24  25.000000
# 32    USD_HKD    S15   930.95421        20  20.000000
# 22    AUD_USD    S15   930.67715        22  22.727273
# 16    USD_CAD    S10   921.64539        20  20.000000
# 39    EUR_GBP     M1   913.24583        12   8.333333
# 43    XAU_USD    S30   836.96500        26  11.538462

# %%
df.sort_values('balance', ascending=False)
# Out:
#    instrument period     balance  numtrade    winrate
# 37    EUR_GBP    S15  1159.94310         9  88.888889
# 10    GBP_USD     S5  1146.97534        23  52.173913
# 19    USD_CAD     M1  1114.90358         8  75.000000
# 5     USD_JPY     S5  1113.51100        19  52.631579
# 6     USD_JPY    S10  1113.26100        22  50.000000
# 35    EUR_GBP     S5  1091.73829        18  50.000000
# 13    GBP_USD    S30  1070.01513        20  45.000000
# 18    USD_CAD    S30  1058.68094        27  40.740741
# 23    AUD_USD    S30  1049.97182        10  50.000000
# 25    USD_CHF     S5  1049.03142        19  42.105263
# 36    EUR_GBP    S10  1049.03112        20  40.000000
# 9     USD_JPY     M1  1039.26100        15  40.000000
# 12    GBP_USD    S15  1038.23154        23  39.130435
# 20    AUD_USD     S5  1029.68872         6  50.000000
# 38    EUR_GBP    S30  1029.07586        12  41.666667
# 11    GBP_USD    S10  1028.15558        21  38.095238
# 44    XAU_USD     M1  1020.46000        18  38.888889
# 0     EUR_USD     S5  1017.87375        22  36.363636
# 8     USD_JPY    S30  1017.79800        25  36.000000
# 40    XAU_USD     S5  1009.80500        24  33.333333
# 3     EUR_USD    S30  1008.29766        18  33.333333
# 1     EUR_USD    S10  1007.69535        23  34.782609
# 4     EUR_USD     M1   998.21317        19  31.578947
# 7     USD_JPY    S15   998.16800        18  33.333333
# 31    USD_HKD    S10   997.91568        22  31.818182
# 30    USD_HKD     S5   997.91557        22  31.818182
# 24    AUD_USD     M1   997.02734        30  33.333333
# 15    USD_CAD     S5   988.23122        19  31.578947
# 14    GBP_USD     M1   978.92879        14  28.571429
# 17    USD_CAD    S15   978.64169        17  29.411765
# 34    USD_HKD     M1   978.34879        20  30.000000
# 29    USD_CHF     M1   978.34672        20  30.000000
# 42    XAU_USD    S15   977.72000        20  30.000000
# 33    USD_HKD    S30   969.14275        15  26.666667
# 21    AUD_USD    S10   959.73763        13  23.076923
# 26    USD_CHF    S10   959.73752        13  23.076923
# 28    USD_CHF    S30   958.87950        22  27.272727
# 27    USD_CHF    S15   950.14069        14  21.428571
# 2     EUR_USD    S15   949.00890        26  26.923077
# 41    XAU_USD    S10   945.27500        24  25.000000
# 32    USD_HKD    S15   930.95421        20  20.000000
# 22    AUD_USD    S15   930.67715        22  22.727273
# 16    USD_CAD    S10   921.64539        20  20.000000
# 39    EUR_GBP     M1   913.24583        12   8.333333
# 43    XAU_USD    S30   836.96500        26  11.538462
